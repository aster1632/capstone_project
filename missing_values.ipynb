# %% [markdown]
# # AUTOSCOUT CAPSTONE PROJECT(The second part)

# %%
#Import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import datetime

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["figure.figsize"] = (12, 8)
pd.set_option('display.max_columns', None)
sns.set_theme(font_scale=1.2, style="darkgrid")
#pd.set_option('display.float_format', lambda x: '%.3' % x)

# %%
df_origin = pd.read_csv("AutoScout_Cleaned_1", index_col=[0])
df = df_origin.copy()
df.head().T
# Out:
#                                                                       0  \
# Model                                                           Audi A1
# Body_Type                                                        Sedans
# Price                                                           15770.0
# Vat                                                      VAT deductible
# Km                                                              56013.0
# Registration_Date                                            2016-01-01
# Prev_Owner                                                          2.0
# Type                                                               Used
# Body_Color                                                        Black
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                     Automatic
# Cylinders                                                           3.0
# Weight                                                           1220.0
# Drive_Chain                                                       front
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media   Bluetooth,Hands-free equipment,On-board comput...
# Extras                   Alloy wheels,Catalytic Converter,Voice Control
# Safety_Security       ABS,Central door lock,Daytime running lights,D...
# Emission_Label                                                      4.0
# Gears                                                               NaN
# Country                                                             NaN
# Consumption_Comb                                                    3.8
# Consumption_City                                                    4.3
# Consumption_Country                                                 3.5
# Hp                                                                 66.0
# Particulate_Filter                                                    1
# Inspection_Time                                              2021-06-01
# Inspection_Situation                                                  1
# Warranty                                                            NaN
# Emission                                                           99.0
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                  Black
# Engine_Size                                                      1422.0
# LastServiceTime                                                     NaN
#
#                                                                       1  \
# Model                                                           Audi A1
# Body_Type                                                        Sedans
# Price                                                           14500.0
# Vat                                                    Price negotiable
# Km                                                              80000.0
# Registration_Date                                            2017-03-01
# Prev_Owner                                                          NaN
# Type                                                               Used
# Body_Color                                                          Red
# Paint_Type                                                          NaN
# Door_Total                                                          3.0
# Seat_Total                                                          4.0
# Gear_Type                                                     Automatic
# Cylinders                                                           4.0
# Weight                                                           1255.0
# Drive_Chain                                                       front
# Fuel                                                            Benzine
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Automatic climate control,Hil...
# Entertainment_Media   Bluetooth,Hands-free equipment,On-board comput...
# Extras                Alloy wheels,Sport seats,Sport suspension,Voic...
# Safety_Security       ABS,Central door lock,Central door lock with r...
# Emission_Label                                                      4.0
# Gears                                                               7.0
# Country                                                             NaN
# Consumption_Comb                                                    5.6
# Consumption_City                                                    7.1
# Consumption_Country                                                 4.7
# Hp                                                                141.0
# Particulate_Filter                                                    0
# Inspection_Time                                                     NaN
# Inspection_Situation                                                  0
# Warranty                                                            NaN
# Emission                                                          129.0
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                   Grey
# Engine_Size                                                      1798.0
# LastServiceTime                                                     NaN
#
#                                                                       2  \
# Model                                                           Audi A1
# Body_Type                                                        Sedans
# Price                                                           14640.0
# Vat                                                      VAT deductible
# Km                                                              83450.0
# Registration_Date                                            2016-02-01
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                        Black
# Paint_Type                                                     Metallic
# Door_Total                                                          4.0
# Seat_Total                                                          4.0
# Gear_Type                                                     Automatic
# Cylinders                                                           NaN
# Weight                                                              NaN
# Drive_Chain                                                       front
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Cruise control,Electrical sid...
# Entertainment_Media                               MP3,On-board computer
# Extras                                       Alloy wheels,Voice Control
# Safety_Security       ABS,Central door lock,Daytime running lights,D...
# Emission_Label                                                      4.0
# Gears                                                               NaN
# Country                                                             NaN
# Consumption_Comb                                                    3.8
# Consumption_City                                                    4.4
# Consumption_Country                                                 3.4
# Hp                                                                 85.0
# Particulate_Filter                                                    1
# Inspection_Time                                                     NaN
# Inspection_Situation                                                  0
# Warranty                                                            NaN
# Emission                                                           99.0
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                  Black
# Engine_Size                                                      1598.0
# LastServiceTime                                                     NaN
#
#                                                                       3  \
# Model                                                           Audi A1
# Body_Type                                                        Sedans
# Price                                                           14500.0
# Vat                                                                 NaN
# Km                                                              73000.0
# Registration_Date                                            2016-08-01
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                        Brown
# Paint_Type                                                     Metallic
# Door_Total                                                          3.0
# Seat_Total                                                          4.0
# Gear_Type                                                     Automatic
# Cylinders                                                           3.0
# Weight                                                           1195.0
# Drive_Chain                                                         NaN
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air suspension,Armrest,Auxiliary heating,Elect...
# Entertainment_Media   Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                           Alloy wheels,Sport seats,Voice Control
# Safety_Security       ABS,Alarm system,Central door lock with remote...
# Emission_Label                                                      NaN
# Gears                                                               6.0
# Country                                                             NaN
# Consumption_Comb                                                    3.8
# Consumption_City                                                    4.3
# Consumption_Country                                                 3.5
# Hp                                                                 66.0
# Particulate_Filter                                                    1
# Inspection_Time                                                     NaN
# Inspection_Situation                                                  0
# Warranty                                                            NaN
# Emission                                                           99.0
# Upholstery_Type                                                     NaN
# Upholstery_Color                                                    NaN
# Engine_Size                                                      1422.0
# LastServiceTime                                                     NaN
#
#                                                                       4
# Model                                                           Audi A1
# Body_Type                                                        Sedans
# Price                                                           16790.0
# Vat                                                                 NaN
# Km                                                              16200.0
# Registration_Date                                            2016-05-01
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                        Black
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                     Automatic
# Cylinders                                                           3.0
# Weight                                                              NaN
# Drive_Chain                                                       front
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media   Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                Alloy wheels,Sport package,Sport suspension,Vo...
# Safety_Security       ABS,Central door lock,Driver-side airbag,Elect...
# Emission_Label                                                      4.0
# Gears                                                               NaN
# Country                                                         Germany
# Consumption_Comb                                                    4.1
# Consumption_City                                                    4.6
# Consumption_Country                                                 3.8
# Hp                                                                 66.0
# Particulate_Filter                                                    1
# Inspection_Time                                                     NaN
# Inspection_Situation                                                  1
# Warranty                                                            NaN
# Emission                                                          109.0
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                  Black
# Engine_Size                                                      1422.0
# LastServiceTime                                                     NaN

# %%
df.isnull().sum()
# Out:
# Model                       0
# Body_Type                  59
# Price                       0
# Vat                      4513
# Km                       1024
# Registration_Date        1597
# Prev_Owner               6640
# Type                        2
# Body_Color                581
# Paint_Type               5772
# Door_Total                212
# Seat_Total                977
# Gear_Type                   0
# Cylinders                5680
# Weight                   6974
# Drive_Chain              6858
# Fuel                        0
# Emission_Class           2920
# Comfort_Convenience       920
# Entertainment_Media      1374
# Extras                   2962
# Safety_Security           982
# Emission_Label           7950
# Gears                    4712
# Country                  8333
# Consumption_Comb         2033
# Consumption_City         2436
# Consumption_Country      2376
# Hp                         86
# Particulate_Filter          0
# Inspection_Time         12450
# Inspection_Situation        0
# Warranty                11066
# Emission                 2435
# Upholstery_Type          4503
# Upholstery_Color         5078
# Engine_Size               176
# LastServiceTime         15353
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15919 entries, 0 to 15918
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 15919 non-null  object
#  1   Body_Type             15860 non-null  object
#  2   Price                 15919 non-null  float64
#  3   Vat                   11406 non-null  object
#  4   Km                    14895 non-null  float64
#  5   Registration_Date     14322 non-null  object
#  6   Prev_Owner            9279 non-null   float64
#  7   Type                  15917 non-null  object
#  8   Body_Color            15338 non-null  object
#  9   Paint_Type            10147 non-null  object
#  10  Door_Total            15707 non-null  float64
#  11  Seat_Total            14942 non-null  float64
#  12  Gear_Type             15919 non-null  object
#  13  Cylinders             10239 non-null  float64
#  14  Weight                8945 non-null   float64
#  15  Drive_Chain           9061 non-null   object
#  16  Fuel                  15919 non-null  object
#  17  Emission_Class        12999 non-null  object
#  18  Comfort_Convenience   14999 non-null  object
#  19  Entertainment_Media   14545 non-null  object
#  20  Extras                12957 non-null  object
#  21  Safety_Security       14937 non-null  object
#  22  Emission_Label        7969 non-null   float64
#  23  Gears                 11207 non-null  float64
#  24  Country               7586 non-null   object
#  25  Consumption_Comb      13886 non-null  float64
#  26  Consumption_City      13483 non-null  float64
#  27  Consumption_Country   13543 non-null  float64
#  28  Hp                    15833 non-null  float64
#  29  Particulate_Filter    15919 non-null  int64
#  30  Inspection_Time       3469 non-null   object
#  31  Inspection_Situation  15919 non-null  int64
#  32  Warranty              4853 non-null   float64
#  33  Emission              13484 non-null  float64
#  34  Upholstery_Type       11416 non-null  object
#  35  Upholstery_Color      10841 non-null  object
#  36  Engine_Size           15743 non-null  float64
#  37  LastServiceTime       566 non-null    object
# dtypes: float64(16), int64(2), object(20)
# memory usage: 4.7+ MB

# %%
df["Registration_Date"] = pd.to_datetime(df["Registration_Date"])
df["Inspection_Time"] = pd.to_datetime(df["Inspection_Time"])

# %%
df.duplicated().value_counts()
# Out:
# False    14433
# True      1486
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().all(axis=1).any()
# Out:
# False

# %%
round(df.isnull().sum()/len(df)*100,2)
# Out:
# Model                    0.00
# Body_Type                0.32
# Price                    0.00
# Vat                     27.77
# Km                       6.23
# Registration_Date        9.54
# Prev_Owner              40.58
# Type                     0.01
# Body_Color               3.55
# Paint_Type              35.29
# Door_Total               0.98
# Seat_Total               5.98
# Gear_Type                0.00
# Cylinders               34.84
# Weight                  44.10
# Drive_Chain             43.73
# Fuel                     0.00
# Emission_Class          18.08
# Comfort_Convenience      5.32
# Entertainment_Media      8.01
# Extras                  17.79
# Safety_Security          5.60
# Emission_Label          49.35
# Gears                   29.13
# Country                 51.67
# Consumption_Comb        12.60
# Consumption_City        15.83
# Consumption_Country     15.42
# Hp                       0.58
# Particulate_Filter       0.00
# Inspection_Time         77.32
# Inspection_Situation     0.00
# Warranty                70.16
# Emission                15.60
# Upholstery_Type         27.12
# Upholstery_Color        32.38
# Engine_Size              1.07
# LastServiceTime         96.23
# dtype: float64

# %%
df.drop(columns="LastServiceTime", inplace=True)

# %%
df["Age"] = (2019 - df["Registration_Date"].dt.year)

# %%
def fillna_with1column(Dataframe:pd.DataFrame, column1, columnNA, method):
    print("Number of NaN Before ModeFunction: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")
    if method == "mode":
        for values in list(Dataframe[column1].unique()):
            condition = (Dataframe[column1] == values)
            mode = list(Dataframe[condition][columnNA].mode())
            if mode != []:
                Dataframe.loc[condition,columnNA] = Dataframe.loc[condition,columnNA].fillna(Dataframe[condition][columnNA].mode()[0])
            else:
                Dataframe.loc[condition,columnNA] = Dataframe.loc[condition,columnNA].fillna(Dataframe[columnNA].mode()[0])
    
    elif method == "ffill":
        for values in list(Dataframe[column1].unique()):
            condition = (Dataframe[column1] == values)
            Dataframe.loc[condition,columnNA] = Dataframe.loc[condition,columnNA].ffill().bfill()
        Dataframe[columnNA] = Dataframe[columnNA].ffill().bfill()
    
    elif method == "bfill":
        for values in list(Dataframe[column1].unique()):
            condition = (Dataframe[column1] == values)
            Dataframe.loc[condition,columnNA] = Dataframe.loc[condition,columnNA].bfill().ffill()
        Dataframe[columnNA] = Dataframe[columnNA].bfill().ffill()
    
    elif method == "mean":
         Dataframe[columnNA] = Dataframe[columnNA].fillna(df.groupby(column1)[columnNA].transform("mean"))
        
    print("Number of NaN After Mode Function: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")

# %%
#Filling NaN values according to 2 columns with mode or median or ffill or mean.

def fillna_with2column(Dataframe:pd.DataFrame, column1, column2, columnNA, method): 
    print(f"Number of NaN Before {method} Function: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")
    if method == "mode":
        for values1 in list(Dataframe[column1].unique()):
            for values2 in list(Dataframe[column2].unique()):
                cond1 = (Dataframe[column1]==values1)
                cond2 = (Dataframe[column1]==values1) & (Dataframe[column2]==values2)
                mode1 = list(Dataframe[cond1][columnNA].mode())
                mode2 = list(Dataframe[cond2][columnNA].mode())
                if mode2 != []:
                    Dataframe.loc[cond2,columnNA]= Dataframe.loc[cond2,columnNA].fillna(Dataframe[cond2][columnNA].mode()[0]).fillna(Dataframe[cond1][columnNA].mode()[0])
                elif mode1 != []:
                    Dataframe.loc[cond1,columnNA]= Dataframe.loc[cond1,columnNA].fillna(Dataframe[cond1][columnNA].mode()[0])
                else:
                    Dataframe.loc[cond2,columnNA] = Dataframe.loc[cond2,columnNA].fillna(Dataframe[columnNA].mode()[0])

    elif method == "median":
        for values1 in list(Dataframe[column1].unique()):
            for values2 in list(Dataframe[column2].unique()):
                cond1 = (Dataframe[column1]==values1)
                cond2 = (Dataframe[column2]==values2) & (Dataframe[column1]==values1)
                Dataframe.loc[cond2,columnNA]= Dataframe.loc[cond2,columnNA].fillna(Dataframe[cond2][columnNA].median()).fillna(Dataframe[cond1][columnNA].median()).fillna(Dataframe[columnNA].median())
                
    elif method == "ffill":           
        for values1 in list(Dataframe[column1].unique()):
            for values2 in list(Dataframe[column2].unique()):
                cond2 = (Dataframe[column1]==values1) & (Dataframe[column2]==values2)
                Dataframe.loc[cond2,columnNA]= Dataframe.loc[cond2,columnNA].ffill().bfill()
                
        for values1 in list(Dataframe[column1].unique()):
            cond1 = (Dataframe[column1]==values1)
            Dataframe.loc[cond1,columnNA]= Dataframe.loc[cond1,columnNA].ffill().bfill()         
           
        Dataframe[columnNA] = Dataframe[columnNA].ffill().bfill()
    
    elif method == "mean":
        Dataframe[columnNA] = Dataframe[columnNA].fillna(df.groupby([column1,column2])[columnNA].transform("mean"))
        
    print(f"Number of NaN After {method} Function: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")

# %%
#Filling NaN values according to 3 columns with mode, median or mean.

def fillna_with3column(Dataframe:pd.DataFrame, column1, column2,column3, columnNA, method): 
    print(f"Number of NaN Before {method} Function: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")
    if method == "mode":
        for values1 in list(Dataframe[column1].unique()):
            for values2 in list(Dataframe[column2].unique()):
                for values3 in list(Dataframe[column3].unique()):

                    cond1 = (Dataframe[column1]==values1)
                    cond2 = (Dataframe[column1]==values1) & (Dataframe[column2]==values2)
                    cond3 = (Dataframe[column1]==values1) & (Dataframe[column2]==values2) & (Dataframe[column3]==values3)
                    mode1 = list(Dataframe[cond1][columnNA].mode())
                    mode2 = list(Dataframe[cond2][columnNA].mode())
                    mode3 = list(Dataframe[cond3][columnNA].mode())
                    
                    if mode3 != []:
                        Dataframe.loc[cond3,columnNA]= Dataframe.loc[cond3,columnNA].fillna(Dataframe[cond3][columnNA].mode()[0]).fillna(Dataframe[cond2][columnNA].mode()[0]).fillna(Dataframe[cond1][columnNA].mode()[0])
                    elif mode2 != []:
                        Dataframe.loc[cond2,columnNA]= Dataframe.loc[cond2,columnNA].fillna(Dataframe[cond2][columnNA].mode()[0]).fillna(Dataframe[cond1][columnNA].mode()[0])
                    elif mode1 != []:
                        Dataframe.loc[cond1,columnNA]= Dataframe.loc[cond1,columnNA].fillna(Dataframe[cond1][columnNA].mode()[0])
                    else:
                        Dataframe.loc[cond2,columnNA] = Dataframe.loc[cond2,columnNA].fillna(Dataframe[columnNA].mode()[0])
    
    elif method == "median":
        for values1 in list(Dataframe[column1].unique()):
            for values2 in list(Dataframe[column2].unique()):
                for values3 in list(Dataframe[column3].unique()):
                
                    cond1 = (Dataframe[column1]==values1)
                    cond2 = (Dataframe[column2]==values2) & (Dataframe[column1]==values1)
                    cond3 = (Dataframe[column1]==values1) & (Dataframe[column2]==values2) & (Dataframe[column3]==values3)
                    Dataframe.loc[cond3,columnNA]= Dataframe.loc[cond3,columnNA].fillna(Dataframe[cond3][columnNA].median()).fillna(Dataframe[cond2][columnNA].median()).fillna(Dataframe[cond1][columnNA].median()).fillna(Dataframe[columnNA].median())
    
    elif method == "mean":
        Dataframe[columnNA] = Dataframe[columnNA].fillna(df.groupby([column1,column2,column3])[columnNA].transform("mean"))
    print(f"Number of NaN After {method} Function: ",Dataframe[columnNA].isnull().sum())
    print(Dataframe[columnNA].value_counts(dropna=False))
    print("------------------")

# %% [markdown]
# # Target Feature - Price

# %%
df.Price.describe()
# Out:
# count    14433.000000
# mean     18121.672279
# std       7425.909096
# min         13.000000
# 25%      12950.000000
# 50%      16950.000000
# 75%      21900.000000
# max      74600.000000
# Name: Price, dtype: float64

# %%
sns.histplot(x="Price", data=df, bins=20, kde=True);

# %%
df["Price_Interval"] = pd.cut(df["Price"],[0,10000,15000,20000,25000,30000,80000])
df["Price_Interval"].value_counts()
# Out:
# (15000, 20000]    4255
# (10000, 15000]    3513
# (20000, 25000]    2816
# (0, 10000]        1887
# (25000, 30000]    1060
# (30000, 80000]     902
# Name: Price_Interval, dtype: int64

# %% [markdown]
# # Numerical Features

# %%
df.select_dtypes(exclude="object").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14433 entries, 0 to 15918
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 14433 non-null  float64
#  1   Km                    13534 non-null  float64
#  2   Registration_Date     13056 non-null  datetime64[ns]
#  3   Prev_Owner            8576 non-null   float64
#  4   Door_Total            14292 non-null  float64
#  5   Seat_Total            13570 non-null  float64
#  6   Cylinders             9404 non-null   float64
#  7   Weight                8068 non-null   float64
#  8   Emission_Label        7310 non-null   float64
#  9   Gears                 10228 non-null  float64
#  10  Consumption_Comb      12615 non-null  float64
#  11  Consumption_City      12148 non-null  float64
#  12  Consumption_Country   12208 non-null  float64
#  13  Hp                    14350 non-null  float64
#  14  Particulate_Filter    14433 non-null  int64
#  15  Inspection_Time       3273 non-null   datetime64[ns]
#  16  Inspection_Situation  14433 non-null  int64
#  17  Warranty              4307 non-null   float64
#  18  Emission              12182 non-null  float64
#  19  Engine_Size           14279 non-null  float64
#  20  Age                   13056 non-null  float64
#  21  Price_Interval        14433 non-null  category
# dtypes: category(1), datetime64[ns](2), float64(17), int64(2)
# memory usage: 2.4 MB

# %%
for i in df.select_dtypes(exclude="O").columns:
    print(f"Null values in {i} column is =  %", round(df[i].isnull().sum()/len(df)*100,2))
# Out:
# Null values in Price column is =  % 0.0
# Null values in Km column is =  % 6.23
# Null values in Registration_Date column is =  % 9.54
# Null values in Prev_Owner column is =  % 40.58
# Null values in Door_Total column is =  % 0.98
# Null values in Seat_Total column is =  % 5.98
# Null values in Cylinders column is =  % 34.84
# Null values in Weight column is =  % 44.1
# Null values in Emission_Label column is =  % 49.35
# Null values in Gears column is =  % 29.13
# Null values in Consumption_Comb column is =  % 12.6
# Null values in Consumption_City column is =  % 15.83
# Null values in Consumption_Country column is =  % 15.42
# Null values in Hp column is =  % 0.58
# Null values in Particulate_Filter column is =  % 0.0
# Null values in Inspection_Time column is =  % 77.32
# Null values in Inspection_Situation column is =  % 0.0
# Null values in Warranty column is =  % 70.16
# Null values in Emission column is =  % 15.6
# Null values in Engine_Size column is =  % 1.07
# Null values in Age column is =  % 9.54
# Null values in Price_Interval column is =  % 0.0

# %%
df.describe(exclude="O").T
# Out:
#                         count unique                  top  freq      first  \
# Price                 14433.0    NaN                  NaN   NaN        NaT
# Km                    13534.0    NaN                  NaN   NaN        NaT
# Registration_Date       13056     47  2018-03-01 00:00:00   664 2016-01-01
# Prev_Owner             8576.0    NaN                  NaN   NaN        NaT
# Door_Total            14292.0    NaN                  NaN   NaN        NaT
# Seat_Total            13570.0    NaN                  NaN   NaN        NaT
# Cylinders              9404.0    NaN                  NaN   NaN        NaT
# Weight                 8068.0    NaN                  NaN   NaN        NaT
# Emission_Label         7310.0    NaN                  NaN   NaN        NaT
# Gears                 10228.0    NaN                  NaN   NaN        NaT
# Consumption_Comb      12615.0    NaN                  NaN   NaN        NaT
# Consumption_City      12148.0    NaN                  NaN   NaN        NaT
# Consumption_Country   12208.0    NaN                  NaN   NaN        NaT
# Hp                    14350.0    NaN                  NaN   NaN        NaT
# Particulate_Filter    14433.0    NaN                  NaN   NaN        NaT
# Inspection_Time          3273     53  2021-06-01 00:00:00   458 2019-01-01
# Inspection_Situation  14433.0    NaN                  NaN   NaN        NaT
# Warranty               4307.0    NaN                  NaN   NaN        NaT
# Emission              12182.0    NaN                  NaN   NaN        NaT
# Engine_Size           14279.0    NaN                  NaN   NaN        NaT
# Age                   13056.0    NaN                  NaN   NaN        NaT
# Price_Interval          14433      6       (15000, 20000]  4255        NaT
#
#                            last          mean           std   min      25%  \
# Price                       NaT  18121.672279   7425.909096  13.0  12950.0
# Km                          NaT  34009.380597  37114.742058   0.0  5991.25
# Registration_Date    2019-12-01           NaN           NaN   NaN      NaN
# Prev_Owner                  NaT      1.058186      0.320707   0.0      1.0
# Door_Total                  NaT      4.655682      0.643762   1.0      4.0
# Seat_Total                  NaT      4.947605      0.475019   2.0      5.0
# Cylinders                   NaT      3.794236      0.418752   1.0      4.0
# Weight                      NaT   1354.579202    224.256342   1.0   1170.0
# Emission_Label              NaT      3.846512      0.677996   1.0      4.0
# Gears                       NaT      5.923739      0.856504   1.0      5.0
# Consumption_Comb            NaT      4.898367      1.690544   0.0      4.1
# Consumption_City            NaT      5.960068       2.00939   0.0      4.7
# Consumption_Country         NaT      4.240867      1.231818   0.0      3.7
# Hp                          NaT     88.444808     26.711531   1.0     66.0
# Particulate_Filter          NaT      0.299799      0.458186   0.0      0.0
# Inspection_Time      2024-03-01           NaN           NaN   NaN      NaN
# Inspection_Situation        NaT      0.255248      0.436016   0.0      0.0
# Warranty                    NaT     22.177153     16.188106   1.0     12.0
# Emission                    NaT    118.117468     20.418061   0.0    104.0
# Engine_Size                 NaT   1427.280832    338.691049   1.0   1229.0
# Age                         NaT      1.536765      1.070347   0.0      1.0
# Price_Interval              NaT           NaN           NaN   NaN      NaN
#
#                           50%      75%       max
# Price                 16950.0  21900.0   74600.0
# Km                    22692.0  49000.0  317000.0
# Registration_Date         NaN      NaN       NaN
# Prev_Owner                1.0      1.0       4.0
# Door_Total                5.0      5.0       7.0
# Seat_Total                5.0      5.0       7.0
# Cylinders                 4.0      4.0       8.0
# Weight                 1293.0   1487.0    2471.0
# Emission_Label            4.0      4.0       5.0
# Gears                     6.0      6.0      50.0
# Consumption_Comb          4.8      5.5      55.0
# Consumption_City          5.8      7.1      66.0
# Consumption_Country       4.2      4.6      44.0
# Hp                       85.0    101.0     294.0
# Particulate_Filter        0.0      1.0       1.0
# Inspection_Time           NaN      NaN       NaN
# Inspection_Situation      0.0      1.0       1.0
# Warranty                 12.0     24.0      72.0
# Emission                116.0    129.0     990.0
# Engine_Size            1461.0   1598.0   16000.0
# Age                       1.0      3.0       3.0
# Price_Interval            NaN      NaN       NaN

# %%
df.select_dtypes(exclude="O").corr().abs()
# Out:
#                          Price        Km  Prev_Owner  Door_Total  Seat_Total  \
# Price                 1.000000  0.388292    0.126587    0.158224    0.247672
# Km                    0.388292  1.000000    0.075815    0.003245    0.010406
# Prev_Owner            0.126587  0.075815    1.000000    0.141950    0.019246
# Door_Total            0.158224  0.003245    0.141950    1.000000    0.113372
# Seat_Total            0.247672  0.010406    0.019246    0.113372    1.000000
# Cylinders             0.008582  0.213879    0.058725    0.074362    0.250920
# Weight                0.413675  0.171147    0.055103    0.166056    0.309875
# Emission_Label        0.096448  0.064324    0.004795    0.095722    0.013023
# Gears                 0.481410  0.040033    0.025948    0.095083    0.089607
# Consumption_Comb      0.157923  0.198648    0.049316    0.021066    0.128277
# Consumption_City      0.158043  0.231761    0.046810    0.050252    0.126942
# Consumption_Country   0.194474  0.230631    0.075869    0.015584    0.141864
# Hp                    0.696250  0.022857    0.012555    0.122280    0.291104
# Particulate_Filter    0.064699  0.262649    0.003630    0.030392    0.044303
# Inspection_Situation  0.002465  0.030489    0.060878    0.117980    0.005726
# Warranty              0.191182  0.286070    0.058192    0.025780    0.068714
# Emission              0.311688  0.200954    0.011646    0.036187    0.247853
# Engine_Size           0.219808  0.269350    0.018833    0.066608    0.174447
# Age                   0.453293  0.725953    0.217153    0.082749    0.089357
#
#                       Cylinders    Weight  Emission_Label     Gears  \
# Price                  0.008582  0.413675        0.096448  0.481410
# Km                     0.213879  0.171147        0.064324  0.040033
# Prev_Owner             0.058725  0.055103        0.004795  0.025948
# Door_Total             0.074362  0.166056        0.095722  0.095083
# Seat_Total             0.250920  0.309875        0.013023  0.089607
# Cylinders              1.000000  0.269336        0.039168  0.134874
# Weight                 0.269336  1.000000        0.021322  0.305033
# Emission_Label         0.039168  0.021322        1.000000  0.139666
# Gears                  0.134874  0.305033        0.139666  1.000000
# Consumption_Comb       0.077573  0.027281        0.060375  0.000805
# Consumption_City       0.098501  0.001840        0.110966  0.017116
# Consumption_Country    0.074251  0.035053        0.029298  0.020737
# Hp                     0.310986  0.582621        0.048971  0.421235
# Particulate_Filter     0.160111  0.225370        0.034353  0.185083
# Inspection_Situation   0.033631  0.014202        0.166477  0.013046
# Warranty               0.199095  0.022966        0.077223  0.016127
# Emission               0.332920  0.267368        0.091552  0.124622
# Engine_Size            0.618450  0.563242        0.014501  0.274915
# Age                    0.150459  0.075889        0.101780  0.089741
#
#                       Consumption_Comb  Consumption_City  Consumption_Country  \
# Price                         0.157923          0.158043             0.194474
# Km                            0.198648          0.231761             0.230631
# Prev_Owner                    0.049316          0.046810             0.075869
# Door_Total                    0.021066          0.050252             0.015584
# Seat_Total                    0.128277          0.126942             0.141864
# Cylinders                     0.077573          0.098501             0.074251
# Weight                        0.027281          0.001840             0.035053
# Emission_Label                0.060375          0.110966             0.029298
# Gears                         0.000805          0.017116             0.020737
# Consumption_Comb              1.000000          0.873565             0.904813
# Consumption_City              0.873565          1.000000             0.902634
# Consumption_Country           0.904813          0.902634             1.000000
# Hp                            0.205839          0.250796             0.207289
# Particulate_Filter            0.190706          0.239856             0.176714
# Inspection_Situation          0.057788          0.089815             0.045612
# Warranty                      0.074583          0.115742             0.084804
# Emission                      0.521212          0.615163             0.528181
# Engine_Size                   0.012199          0.007211             0.016349
# Age                           0.224103          0.271519             0.294398
#
#                             Hp  Particulate_Filter  Inspection_Situation  \
# Price                 0.696250            0.064699              0.002465
# Km                    0.022857            0.262649              0.030489
# Prev_Owner            0.012555            0.003630              0.060878
# Door_Total            0.122280            0.030392              0.117980
# Seat_Total            0.291104            0.044303              0.005726
# Cylinders             0.310986            0.160111              0.033631
# Weight                0.582621            0.225370              0.014202
# Emission_Label        0.048971            0.034353              0.166477
# Gears                 0.421235            0.185083              0.013046
# Consumption_Comb      0.205839            0.190706              0.057788
# Consumption_City      0.250796            0.239856              0.089815
# Consumption_Country   0.207289            0.176714              0.045612
# Hp                    1.000000            0.148635              0.049454
# Particulate_Filter    0.148635            1.000000              0.069555
# Inspection_Situation  0.049454            0.069555              1.000000
# Warranty              0.076883            0.031027              0.301098
# Emission              0.464690            0.120464              0.109199
# Engine_Size           0.499567            0.359742              0.009198
# Age                   0.066671            0.183119              0.017939
#
#                       Warranty  Emission  Engine_Size       Age
# Price                 0.191182  0.311688     0.219808  0.453293
# Km                    0.286070  0.200954     0.269350  0.725953
# Prev_Owner            0.058192  0.011646     0.018833  0.217153
# Door_Total            0.025780  0.036187     0.066608  0.082749
# Seat_Total            0.068714  0.247853     0.174447  0.089357
# Cylinders             0.199095  0.332920     0.618450  0.150459
# Weight                0.022966  0.267368     0.563242  0.075889
# Emission_Label        0.077223  0.091552     0.014501  0.101780
# Gears                 0.016127  0.124622     0.274915  0.089741
# Consumption_Comb      0.074583  0.521212     0.012199  0.224103
# Consumption_City      0.115742  0.615163     0.007211  0.271519
# Consumption_Country   0.084804  0.528181     0.016349  0.294398
# Hp                    0.076883  0.464690     0.499567  0.066671
# Particulate_Filter    0.031027  0.120464     0.359742  0.183119
# Inspection_Situation  0.301098  0.109199     0.009198  0.017939
# Warranty              1.000000  0.178748     0.103312  0.304312
# Emission              0.178748  1.000000     0.261193  0.248763
# Engine_Size           0.103312  0.261193     1.000000  0.173863
# Age                   0.304312  0.248763     0.173863  1.000000

# %%
def numeric_look(column1):
    print("----DESCRIBE : --------")
    print(df[column1].describe())
    print("----TOTAL NULL : --------")
    print(df[column1].isnull().sum())
    print("----PERCENTAGE OF NULL : --------")
    print("%",round(df[column1].isnull().sum() / df.shape[0]*100, 2))
    print("----CORELATION : --------")
    print(df.corr()[column1].abs())
    print("----VALUE COUNTS : --------")
    print(df[column1].value_counts(dropna=False))

# %% [markdown]
# # Km

# %%
numeric_look("Km")
# Out:
# ----DESCRIBE : --------
# count     13534.000000
# mean      34009.380597
# std       37114.742058
# min           0.000000
# 25%        5991.250000
# 50%       22692.000000
# 75%       49000.000000
# max      317000.000000
# Name: Km, dtype: float64
# ----TOTAL NULL : --------
# 899
# ----PERCENTAGE OF NULL : --------
# % 6.23
# ----CORELATION : --------
# Price                   0.388292
# Km                      1.000000
# Prev_Owner              0.075815
# Door_Total              0.003245
# Seat_Total              0.010406
# Cylinders               0.213879
# Weight                  0.171147
# Emission_Label          0.064324
# Gears                   0.040033
# Consumption_Comb        0.198648
# Consumption_City        0.231761
# Consumption_Country     0.230631
# Hp                      0.022857
# Particulate_Filter      0.262649
# Inspection_Situation    0.030489
# Warranty                0.286070
# Emission                0.200954
# Engine_Size             0.269350
# Age                     0.725953
# Name: Km, dtype: float64
# ----VALUE COUNTS : --------
# NaN       899
# 10.0      827
# 1.0       306
# 5.0       138
# 50.0      127
#          ...
# 3105.0      1
# 2890.0      1
# 3806.0      1
# 6300.0      1
# 57.0        1
# Name: Km, Length: 6690, dtype: int64

# %%
sns.histplot(df["Km"], bins=20, kde=True);

# %%
df.groupby(["Age","Type"])["Km"].mean()
# Out:
# Age  Type
# 0.0  Demonstration      3385.441227
#      Employee's car     4969.121495
#      New                  53.530864
#      Pre-registered      121.349153
#      Used               3953.514946
# 1.0  Demonstration      8431.094488
#      Employee's car    19088.158960
#      New                  53.500000
#      Pre-registered      502.468468
#      Used              18808.357143
# 2.0  Demonstration     25327.296296
#      Employee's car    37248.409639
#      Pre-registered     2085.625000
#      Used              42745.484195
# 3.0  Demonstration     45500.000000
#      Employee's car    62493.466667
#      Pre-registered       10.000000
#      Used              76682.966071
# Name: Km, dtype: float64

# %%
fillna_with3column(df,"Model","Age","Type","Km","mean")
# Out:
# Number of NaN Before mean Function:  899
# NaN       899
# 10.0      827
# 1.0       306
# 5.0       138
# 50.0      127
#          ...
# 3105.0      1
# 2890.0      1
# 3806.0      1
# 6300.0      1
# 57.0        1
# Name: Km, Length: 6690, dtype: int64
# ------------------
# Number of NaN After mean Function:  726
# 10.0      831
# NaN       726
# 1.0       306
# 5.0       138
# 50.0      127
#          ...
# 1794.0      1
# 5586.0      1
# 199.0       1
# 3521.0      1
# 57.0        1
# Name: Km, Length: 6722, dtype: int64
# ------------------

# %%
fillna_with2column(df,"Model","Type","Km","mean")
# Out:
# Number of NaN Before mean Function:  726
# 10.0      831
# NaN       726
# 1.0       306
# 5.0       138
# 50.0      127
#          ...
# 1794.0      1
# 5586.0      1
# 199.0       1
# 3521.0      1
# 57.0        1
# Name: Km, Length: 6722, dtype: int64
# ------------------
# Number of NaN After mean Function:  19
# 10.000000      831
# 1.000000       306
# 15.888889      188
# 11.465986      180
# 5.000000       138
#               ...
# 42.000000        1
# 1794.000000      1
# 5586.000000      1
# 199.000000       1
# 57.000000        1
# Name: Km, Length: 6732, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Model","Km","mean")
# Out:
# Number of NaN Before ModeFunction:  19
# 10.000000      831
# 1.000000       306
# 15.888889      188
# 11.465986      180
# 5.000000       138
#               ...
# 42.000000        1
# 1794.000000      1
# 5586.000000      1
# 199.000000       1
# 57.000000        1
# Name: Km, Length: 6732, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 10.000000      831
# 1.000000       306
# 15.888889      188
# 11.465986      180
# 5.000000       138
#               ...
# 1794.000000      1
# 5586.000000      1
# 199.000000       1
# 3521.000000      1
# 57.000000        1
# Name: Km, Length: 6732, dtype: int64
# ------------------

# %% [markdown]
# # Registration_Date & Age

# %%
numeric_look("Age")
# Out:
# ----DESCRIBE : --------
# count    13056.000000
# mean         1.536765
# std          1.070347
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max          3.000000
# Name: Age, dtype: float64
# ----TOTAL NULL : --------
# 1377
# ----PERCENTAGE OF NULL : --------
# % 9.54
# ----CORELATION : --------
# Price                   0.453293
# Km                      0.728965
# Prev_Owner              0.217153
# Door_Total              0.082749
# Seat_Total              0.089357
# Cylinders               0.150459
# Weight                  0.075889
# Emission_Label          0.101780
# Gears                   0.089741
# Consumption_Comb        0.224103
# Consumption_City        0.271519
# Consumption_Country     0.294398
# Hp                      0.066671
# Particulate_Filter      0.183119
# Inspection_Situation    0.017939
# Warranty                0.304312
# Emission                0.248763
# Engine_Size             0.173863
# Age                     1.000000
# Name: Age, dtype: float64
# ----VALUE COUNTS : --------
# 1.0    4298
# 3.0    3320
# 2.0    2903
# 0.0    2535
# NaN    1377
# Name: Age, dtype: int64

# %%
sns.countplot(x="Age", data=df);

# %%
sns.scatterplot(x="Km",y="Price", hue="Age", data=df)
plt.xlim(0,50000);

# %%
df["Km_Interval"] =pd.cut(df["Km"], bins=[-1,5000,15000,30000,60000,100000,350000])
df["Km_Interval"].value_counts()
# Out:
# (-1, 5000]          4111
# (15000, 30000]      3330
# (30000, 60000]      2330
# (5000, 15000]       1971
# (60000, 100000]     1818
# (100000, 350000]     873
# Name: Km_Interval, dtype: int64

# %%
fillna_with2column(df,"Km_Interval","Type","Age","mode")
# Out:
# Number of NaN Before mode Function:  1377
# 1.0    4298
# 3.0    3320
# 2.0    2903
# 0.0    2535
# NaN    1377
# Name: Age, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 1.0    4306
# 0.0    3894
# 3.0    3325
# 2.0    2908
# Name: Age, dtype: int64
# ------------------

# %%
df_regist = 2019 - df["Age"]
df_regist = pd.to_datetime(df_regist, format="%Y")
df["Registration_Date"].fillna(df_regist, inplace=True)
df["Registration_Date"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Prev_Owner

# %%
numeric_look("Prev_Owner")
# Out:
# ----DESCRIBE : --------
# count    8576.000000
# mean        1.058186
# std         0.320707
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: Prev_Owner, dtype: float64
# ----TOTAL NULL : --------
# 5857
# ----PERCENTAGE OF NULL : --------
# % 40.58
# ----CORELATION : --------
# Price                   0.126587
# Km                      0.100321
# Prev_Owner              1.000000
# Door_Total              0.141950
# Seat_Total              0.019246
# Cylinders               0.058725
# Weight                  0.055103
# Emission_Label          0.004795
# Gears                   0.025948
# Consumption_Comb        0.049316
# Consumption_City        0.046810
# Consumption_Country     0.075869
# Hp                      0.012555
# Particulate_Filter      0.003630
# Inspection_Situation    0.060878
# Warranty                0.058192
# Emission                0.011646
# Engine_Size             0.018833
# Age                     0.279425
# Name: Prev_Owner, dtype: float64
# ----VALUE COUNTS : --------
# 1.0    7732
# NaN    5857
# 2.0     642
# 0.0     183
# 3.0      17
# 4.0       2
# Name: Prev_Owner, dtype: int64

# %%
sns.countplot(x="Prev_Owner", data=df);

# %%
df[(df["Prev_Owner"].isnull()) & (df["Type"]=="New") | (df["Type"]=="Pre-registered")].sample(5)
# Out:
#             Model Body_Type    Price             Vat          Km  \
# 10370  Opel Corsa    Sedans  11300.0             NaN   10.000000
# 5131      Audi A3    Sedans  26200.0  VAT deductible  100.000000
# 7364   Opel Astra    Sedans  14958.0  VAT deductible    1.000000
# 1976      Audi A1   Compact  27780.0  VAT deductible   15.888889
# 9860   Opel Corsa   Compact  16691.0  VAT deductible   51.000000
#
#       Registration_Date  Prev_Owner            Type Body_Color Paint_Type  \
# 10370        2019-05-01         1.0  Pre-registered      White        NaN
# 5131         2019-03-01         NaN  Pre-registered     Silver   Metallic
# 7364         2019-01-01         NaN             New        NaN   Metallic
# 1976         2019-01-01         NaN             New       Grey   Metallic
# 9860         2019-06-01         1.0  Pre-registered       Grey   Metallic
#
#        Door_Total  Seat_Total  Gear_Type  Cylinders  Weight Drive_Chain  \
# 10370         5.0         5.0     Manual        4.0  1163.0       front
# 5131          5.0         5.0  Automatic        4.0     NaN       front
# 7364          5.0         5.0     Manual        3.0     NaN       front
# 1976          5.0         5.0  Automatic        3.0  1200.0       front
# 9860          5.0         5.0  Automatic        NaN     NaN       front
#
#           Fuel Emission_Class  \
# 10370  Benzine        Euro 6d
# 5131    Diesel            NaN
# 7364   Benzine        Euro 6d
# 1976   Benzine         Euro 6
# 9860   Benzine        Euro 6d
#
#                                      Comfort_Convenience  \
# 10370  Air conditioning,Leather steering wheel,Multi-...
# 5131   Electrical side mirrors,Leather steering wheel...
# 7364                      Air conditioning,Power windows
# 1976   Air conditioning,Armrest,Automatic climate con...
# 9860   Air conditioning,Cruise control,Electrically h...
#
#                                      Entertainment_Media  \
# 10370              Bluetooth,On-board computer,Radio,USB
# 5131        Bluetooth,Hands-free equipment,MP3,Radio,USB
# 7364                                                 NaN
# 1976                                               Radio
# 9860   Bluetooth,Hands-free equipment,MP3,On-board co...
#
#                                                Extras  \
# 10370                       Alloy wheels,Touch screen
# 5131                                     Alloy wheels
# 7364                                              NaN
# 1976   Alloy wheels,Catalytic Converter,Voice Control
# 9860                        Alloy wheels,Touch screen
#
#                                          Safety_Security  Emission_Label  \
# 10370  ABS,Central door lock,Daytime running lights,D...             NaN
# 5131   ABS,Central door lock,Driver-side airbag,Isofi...             1.0
# 7364   ABS,Central door lock,Daytime running lights,D...             4.0
# 1976   ABS,Central door lock,Daytime running lights,D...             4.0
# 9860   ABS,Central door lock,Central door lock with r...             4.0
#
#        Gears         Country  Consumption_Comb  Consumption_City  \
# 10370    5.0           Italy               5.3               6.6
# 5131     7.0             NaN               3.9               4.1
# 7364     5.0  European Union               5.0               5.9
# 1976     NaN         Germany               4.9               5.9
# 9860     6.0         Germany               6.9               8.6
#
#        Consumption_Country    Hp  Particulate_Filter Inspection_Time  \
# 10370                  4.5  51.0                   0             NaT
# 5131                   3.7  85.0                   0             NaT
# 7364                   4.5  77.0                   0             NaT
# 1976                   4.3  85.0                   0             NaT
# 9860                   6.0  66.0                   0             NaT
#
#        Inspection_Situation  Warranty  Emission Upholstery_Type  \
# 10370                     0       NaN     124.0             NaN
# 5131                      0       NaN     103.0           Cloth
# 7364                      0       NaN     115.0           Cloth
# 1976                      0       NaN     111.0           Cloth
# 9860                      1      24.0     157.0           Cloth
#
#       Upholstery_Color  Engine_Size  Age  Price_Interval Km_Interval
# 10370              NaN       1229.0  0.0  (10000, 15000]  (-1, 5000]
# 5131             Other       1598.0  0.0  (25000, 30000]  (-1, 5000]
# 7364               NaN        999.0  0.0  (10000, 15000]  (-1, 5000]
# 1976             Other        999.0  0.0  (25000, 30000]  (-1, 5000]
# 9860             Black       1398.0  0.0  (15000, 20000]  (-1, 5000]

# %%
df.loc[df[(df["Prev_Owner"].isnull()) & (df["Type"]=="New") | (df["Type"]=="Pre-registered")].index, "Prev_Owner"] = 0

# %%
df.groupby("Prev_Owner")["Km"].mean()
# Out:
# Prev_Owner
# 0.0      547.336771
# 1.0    39270.644604
# 2.0    43371.130094
# 3.0    48588.470588
# 4.0    38350.000000
# Name: Km, dtype: float64

# %%
df.loc[df[(df["Prev_Owner"].isnull()) & (df["Km"]<500)].index, "Prev_Owner"] = 0

# %%
df.groupby(["Age","Type"])["Prev_Owner"].value_counts(normalize=True)
# Out:
# Age  Type            Prev_Owner
# 0.0  Demonstration   1.0           0.838710
#                      0.0           0.159140
#                      2.0           0.002151
#      Employee's car  1.0           0.774194
#                      0.0           0.215054
#                      2.0           0.010753
#      New             0.0           0.990162
#                      1.0           0.009838
#      Pre-registered  0.0           1.000000
#      Used            1.0           0.600000
#                      0.0           0.394690
#                      2.0           0.005310
# 1.0  Demonstration   1.0           0.859813
#                      0.0           0.121495
#                      2.0           0.018692
#      Employee's car  1.0           0.959615
#                      0.0           0.025000
#                      2.0           0.015385
#      New             0.0           0.666667
#                      1.0           0.333333
#      Pre-registered  0.0           1.000000
#      Used            1.0           0.951906
#                      2.0           0.026430
#                      0.0           0.021664
# 2.0  Demonstration   1.0           0.826087
#                      2.0           0.130435
#                      0.0           0.043478
#      Employee's car  1.0           0.933333
#                      0.0           0.066667
#      Pre-registered  0.0           1.000000
#      Used            1.0           0.867731
#                      2.0           0.123147
#                      0.0           0.004561
#                      3.0           0.003991
#                      4.0           0.000570
# 3.0  Demonstration   1.0           1.000000
#      Employee's car  1.0           1.000000
#      Pre-registered  0.0           1.000000
#      Used            1.0           0.835653
#                      2.0           0.154019
#                      0.0           0.005388
#                      3.0           0.004490
#                      4.0           0.000449
# Name: Prev_Owner, dtype: float64

# %%
fillna_with2column(df,"Age","Type","Prev_Owner","mode")
# Out:
# Number of NaN Before mode Function:  3787
# 1.0    7043
# NaN    3787
# 0.0    2946
# 2.0     638
# 3.0      17
# 4.0       2
# Name: Prev_Owner, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 1.0    10830
# 0.0     2946
# 2.0      638
# 3.0       17
# 4.0        2
# Name: Prev_Owner, dtype: int64
# ------------------

# %% [markdown]
# # Door_Total

# %%
numeric_look("Door_Total")
# Out:
# ----DESCRIBE : --------
# count    14292.000000
# mean         4.655682
# std          0.643762
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          7.000000
# Name: Door_Total, dtype: float64
# ----TOTAL NULL : --------
# 141
# ----PERCENTAGE OF NULL : --------
# % 0.98
# ----CORELATION : --------
# Price                   0.158224
# Km                      0.010805
# Prev_Owner              0.109105
# Door_Total              1.000000
# Seat_Total              0.113372
# Cylinders               0.074362
# Weight                  0.166056
# Emission_Label          0.095722
# Gears                   0.095083
# Consumption_Comb        0.021066
# Consumption_City        0.050252
# Consumption_Country     0.015584
# Hp                      0.122280
# Particulate_Filter      0.030392
# Inspection_Situation    0.117980
# Warranty                0.025780
# Emission                0.036187
# Engine_Size             0.066608
# Age                     0.093838
# Name: Door_Total, dtype: float64
# ----VALUE COUNTS : --------
# 5.0    10516
# 4.0     2823
# 3.0      757
# 2.0      194
# NaN      141
# 1.0        1
# 7.0        1
# Name: Door_Total, dtype: int64

# %%
sns.countplot(x="Door_Total", data=df);

# %%
df.groupby("Model")["Door_Total"].value_counts(normalize=True)
# Out:
# Model           Door_Total
# Audi A1         5.0           0.679444
#                 4.0           0.200927
#                 3.0           0.088458
#                 2.0           0.031171
# Audi A2         5.0           1.000000
# Audi A3         5.0           0.728117
#                 4.0           0.225080
#                 3.0           0.037156
#                 2.0           0.009646
# Opel Astra      5.0           0.791775
#                 4.0           0.206494
#                 3.0           0.001732
# Opel Corsa      5.0           0.595262
#                 3.0           0.216683
#                 4.0           0.142152
#                 2.0           0.045903
# Opel Insignia   5.0           0.705637
#                 4.0           0.294363
# Renault Clio    5.0           0.885734
#                 4.0           0.113590
#                 1.0           0.000676
# Renault Duster  5.0           1.000000
# Renault Espace  5.0           0.909611
#                 4.0           0.089245
#                 7.0           0.001144
# Name: Door_Total, dtype: float64

# %%
fillna_with1column(df,"Model","Door_Total","mode")
# Out:
# Number of NaN Before ModeFunction:  141
# 5.0    10516
# 4.0     2823
# 3.0      757
# 2.0      194
# NaN      141
# 1.0        1
# 7.0        1
# Name: Door_Total, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 5.0    10657
# 4.0     2823
# 3.0      757
# 2.0      194
# 1.0        1
# 7.0        1
# Name: Door_Total, dtype: int64
# ------------------

# %% [markdown]
# # Seat_Total

# %%
sns.countplot(x="Seat_Total", data=df);

# %%
df.groupby(["Model"])["Seat_Total"].value_counts(normalize=True)
# Out:
# Model           Seat_Total
# Audi A1         5.0           0.543968
#                 4.0           0.455148
#                 3.0           0.000442
#                 6.0           0.000442
# Audi A2         5.0           1.000000
# Audi A3         5.0           0.990758
#                 4.0           0.009242
# Opel Astra      5.0           0.997710
#                 4.0           0.002290
# Opel Corsa      5.0           0.993884
#                 4.0           0.003568
#                 2.0           0.002548
# Opel Insignia   5.0           0.998706
#                 4.0           0.000863
#                 2.0           0.000431
# Renault Clio    5.0           0.936138
#                 2.0           0.060105
#                 4.0           0.003757
# Renault Duster  5.0           1.000000
# Renault Espace  5.0           0.595084
#                 7.0           0.402329
#                 4.0           0.001294
#                 6.0           0.001294
# Name: Seat_Total, dtype: float64

# %%
fillna_with2column(df,"Model","Body_Type","Seat_Total","mode")
# Out:
# Number of NaN Before mode Function:  863
# 5.0    12095
# 4.0     1075
# NaN      863
# 7.0      311
# 2.0       86
# 6.0        2
# 3.0        1
# Name: Seat_Total, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 5.0    12956
# 4.0     1076
# 7.0      311
# 2.0       87
# 6.0        2
# 3.0        1
# Name: Seat_Total, dtype: int64
# ------------------

# %% [markdown]
# # Engine_Size

# %%
numeric_look("Engine_Size")
# Out:
# ----DESCRIBE : --------
# count    14279.000000
# mean      1427.280832
# std        338.691049
# min          1.000000
# 25%       1229.000000
# 50%       1461.000000
# 75%       1598.000000
# max      16000.000000
# Name: Engine_Size, dtype: float64
# ----TOTAL NULL : --------
# 154
# ----PERCENTAGE OF NULL : --------
# % 1.07
# ----CORELATION : --------
# Price                   0.219808
# Km                      0.269148
# Prev_Owner              0.116530
# Door_Total              0.065738
# Seat_Total              0.165909
# Cylinders               0.618450
# Weight                  0.563242
# Emission_Label          0.014501
# Gears                   0.274915
# Consumption_Comb        0.012199
# Consumption_City        0.007211
# Consumption_Country     0.016349
# Hp                      0.499567
# Particulate_Filter      0.359742
# Inspection_Situation    0.009198
# Warranty                0.103312
# Emission                0.261193
# Engine_Size             1.000000
# Age                     0.187546
# Name: Engine_Size, dtype: float64
# ----VALUE COUNTS : --------
# 1598.0    4391
# 999.0     2263
# 1398.0    1261
# 1399.0     672
# 1956.0     636
#           ...
# 1198.0       1
# 1195.0       1
# 2800.0       1
# 2967.0       1
# 1800.0       1
# Name: Engine_Size, Length: 80, dtype: int64

# %%
sns.boxplot(df["Engine_Size"])
# Out:
# <AxesSubplot:xlabel='Engine_Size'>

# %%
df.loc[df[df["Engine_Size"]>10000].index,"Engine_Size"] = 1600

# %%
df[df["Engine_Size"]<500]
# Out:
#                 Model      Body_Type    Price             Vat            Km  \
# 7809       Opel Astra         Sedans  23940.0  VAT deductible     12.000000
# 7810       Opel Astra         Sedans  23940.0  VAT deductible     12.000000
# 7811       Opel Astra         Sedans  23940.0  VAT deductible     12.000000
# 7812       Opel Astra         Sedans  23940.0  VAT deductible     12.000000
# 8128       Opel Astra  Station wagon  18830.0  VAT deductible     10.000000
# 10194      Opel Corsa        Compact  10940.0  VAT deductible     12.000000
# 10559   Opel Insignia  Station wagon  16950.0  VAT deductible  84700.000000
# 12467   Opel Insignia  Station wagon  37490.0  VAT deductible   4056.359477
# 12473   Opel Insignia  Station wagon  34490.0  VAT deductible   4056.359477
# 12484   Opel Insignia         Sedans  33990.0  VAT deductible     10.000000
# 12499   Opel Insignia  Station wagon  36990.0  VAT deductible   4056.359477
# 12501   Opel Insignia  Station wagon  36990.0  VAT deductible     70.000000
# 12554   Opel Insignia  Station wagon  33590.0  VAT deductible   1574.000000
# 12604   Opel Insignia  Station wagon  28990.0  VAT deductible   2254.000000
# 12670   Opel Insignia  Station wagon  29990.0  VAT deductible   4056.359477
# 12750   Opel Insignia         Sedans  41490.0  VAT deductible     10.000000
# 12768   Opel Insignia  Station wagon  39190.0  VAT deductible     11.465986
# 12769   Opel Insignia        Compact  38990.0  VAT deductible   1852.000000
# 12781   Opel Insignia  Station wagon  36500.0  VAT deductible   4056.359477
# 12783   Opel Insignia        Compact  36490.0  VAT deductible   3291.000000
# 12786   Opel Insignia  Station wagon  36780.0  VAT deductible     70.000000
# 12790   Opel Insignia  Station wagon  35990.0  VAT deductible   2348.000000
# 12796   Opel Insignia         Sedans  35990.0  VAT deductible    136.000000
# 12798   Opel Insignia  Station wagon  33990.0  VAT deductible   3582.000000
# 12800   Opel Insignia  Station wagon  33790.0  VAT deductible   6446.000000
# 12815   Opel Insignia  Station wagon  32990.0  VAT deductible      6.000000
# 12823   Opel Insignia  Station wagon  28500.0  VAT deductible   4056.359477
# 12835   Opel Insignia         Sedans  34925.0  VAT deductible   4631.000000
# 12848   Opel Insignia  Station wagon  33990.0  VAT deductible   1798.000000
# 12849   Opel Insignia  Station wagon  33990.0  VAT deductible      8.000000
# 13904    Renault Clio         Sedans   9490.0             NaN  26000.000000
# 13912    Renault Clio         Sedans   9400.0             NaN  17000.000000
# 14198    Renault Clio         Sedans   9680.0             NaN  44235.000000
# 14284    Renault Clio         Sedans   9999.0  VAT deductible  18008.000000
# 14314    Renault Clio         Sedans   9999.0  VAT deductible  11314.000000
# 14315    Renault Clio         Sedans   9999.0  VAT deductible   8031.000000
# 14319    Renault Clio         Sedans   9999.0  VAT deductible  11004.000000
# 14320    Renault Clio         Sedans   9999.0  VAT deductible  15674.000000
# 14321    Renault Clio         Sedans   9999.0  VAT deductible  14039.000000
# 14322    Renault Clio         Sedans   9999.0  VAT deductible  15678.000000
# 14324    Renault Clio         Sedans   9999.0  VAT deductible  30000.000000
# 14325    Renault Clio         Sedans   9999.0  VAT deductible  14532.000000
# 14326    Renault Clio         Sedans   9999.0  VAT deductible  14066.000000
# 14327    Renault Clio         Sedans   9999.0  VAT deductible  21543.000000
# 14328    Renault Clio         Sedans   9999.0  VAT deductible  17364.000000
# 15574  Renault Espace            Van  31900.0             NaN      1.000000
#
#       Registration_Date  Prev_Owner            Type Body_Color Paint_Type  \
# 7809         2019-03-01         0.0  Pre-registered      Black   Metallic
# 7810         2019-03-01         0.0  Pre-registered     Silver   Metallic
# 7811         2019-03-01         0.0  Pre-registered       Grey   Metallic
# 7812         2019-04-01         0.0  Pre-registered       Blue   Metallic
# 8128         2019-04-01         0.0   Demonstration      White        NaN
# 10194        2019-04-01         0.0  Pre-registered      White        NaN
# 10559        2016-06-01         1.0            Used     Silver   Metallic
# 12467        2019-06-01         1.0   Demonstration       Grey        NaN
# 12473        2019-05-01         1.0   Demonstration     Silver        NaN
# 12484        2019-05-01         1.0   Demonstration      Black   Metallic
# 12499        2019-04-01         1.0   Demonstration        Red        NaN
# 12501        2019-05-01         1.0   Demonstration      White        NaN
# 12554        2019-02-01         1.0   Demonstration     Silver   Metallic
# 12604        2019-03-01         1.0   Demonstration       Grey   Metallic
# 12670        2019-06-01         1.0   Demonstration       Grey   Metallic
# 12750        2019-01-01         0.0             New      Black   Metallic
# 12768        2019-01-01         0.0             New     Silver   Metallic
# 12769        2019-04-01         1.0   Demonstration      Black   Metallic
# 12781        2019-06-01         1.0   Demonstration      White   Metallic
# 12783        2019-03-01         1.0   Demonstration      White   Metallic
# 12786        2019-04-01         1.0   Demonstration     Silver   Metallic
# 12790        2019-04-01         1.0   Demonstration      White        NaN
# 12796        2019-06-01         0.0   Demonstration      Black   Metallic
# 12798        2019-05-01         1.0   Demonstration        Red        NaN
# 12800        2019-01-01         1.0   Demonstration      Black   Metallic
# 12815        2019-03-01         1.0   Demonstration     Silver   Metallic
# 12823        2019-06-01         1.0   Demonstration       Grey   Metallic
# 12835        2019-02-01         1.0   Demonstration      Black   Metallic
# 12848        2019-05-01         1.0   Demonstration       Grey   Metallic
# 12849        2019-03-01         1.0   Demonstration       Grey   Metallic
# 13904        2017-03-01         1.0            Used      White        NaN
# 13912        2017-11-01         1.0            Used      Black   Metallic
# 14198        2017-06-01         1.0            Used     Silver   Metallic
# 14284        2018-06-01         1.0            Used      White        NaN
# 14314        2018-06-01         1.0            Used      White        NaN
# 14315        2018-06-01         1.0            Used      White        NaN
# 14319        2018-06-01         1.0            Used      White        NaN
# 14320        2018-06-01         1.0            Used      White        NaN
# 14321        2018-06-01         1.0            Used      White        NaN
# 14322        2018-06-01         1.0            Used      White        NaN
# 14324        2018-06-01         1.0            Used      White        NaN
# 14325        2018-06-01         1.0            Used      White        NaN
# 14326        2018-06-01         1.0            Used      White        NaN
# 14327        2018-06-01         1.0            Used      White        NaN
# 14328        2018-06-01         1.0            Used      White        NaN
# 15574        2019-02-01         0.0  Pre-registered      White        NaN
#
#        Door_Total  Seat_Total  Gear_Type  Cylinders  Weight Drive_Chain  \
# 7809          5.0         5.0  Automatic        NaN  1352.0       front
# 7810          5.0         5.0  Automatic        NaN  1352.0       front
# 7811          5.0         5.0  Automatic        NaN  1352.0       front
# 7812          5.0         5.0  Automatic        NaN  1352.0       front
# 8128          5.0         5.0     Manual        NaN     NaN       front
# 10194         3.0         5.0     Manual        NaN  1162.0       front
# 10559         5.0         5.0  Automatic        NaN     NaN         NaN
# 12467         5.0         5.0  Automatic        NaN     NaN       front
# 12473         5.0         5.0  Automatic        NaN     NaN       front
# 12484         5.0         5.0  Automatic        NaN     NaN       front
# 12499         5.0         5.0  Automatic        NaN     NaN       front
# 12501         5.0         5.0  Automatic        NaN     NaN       front
# 12554         5.0         5.0  Automatic        NaN     NaN       front
# 12604         5.0         5.0  Automatic        NaN     NaN       front
# 12670         5.0         5.0  Automatic        NaN     NaN       front
# 12750         5.0         5.0     Manual        NaN     NaN       front
# 12768         5.0         5.0     Manual        NaN     NaN       front
# 12769         5.0         5.0     Manual        NaN     NaN       front
# 12781         5.0         5.0     Manual        NaN     NaN       front
# 12783         5.0         5.0     Manual        NaN     NaN       front
# 12786         5.0         5.0     Manual        NaN     NaN       front
# 12790         5.0         5.0     Manual        NaN     NaN       front
# 12796         5.0         5.0     Manual        NaN     NaN       front
# 12798         5.0         5.0     Manual        NaN     NaN       front
# 12800         5.0         5.0     Manual        NaN     NaN         4WD
# 12815         5.0         5.0     Manual        NaN     NaN       front
# 12823         5.0         5.0     Manual        NaN     NaN       front
# 12835         5.0         5.0     Manual        NaN     NaN       front
# 12848         5.0         5.0     Manual        NaN     NaN       front
# 12849         5.0         5.0     Manual        NaN     NaN       front
# 13904         5.0         5.0     Manual        4.0     NaN         NaN
# 13912         5.0         5.0     Manual        NaN     NaN         NaN
# 14198         5.0         5.0     Manual        4.0     NaN         NaN
# 14284         5.0         5.0     Manual        4.0     NaN         NaN
# 14314         5.0         5.0     Manual        4.0     NaN         NaN
# 14315         5.0         5.0     Manual        4.0     NaN         NaN
# 14319         5.0         5.0     Manual        4.0     NaN         NaN
# 14320         5.0         5.0     Manual        4.0     NaN         NaN
# 14321         5.0         5.0     Manual        4.0     NaN         NaN
# 14322         5.0         5.0     Manual        4.0     NaN         NaN
# 14324         5.0         5.0     Manual        4.0     NaN         NaN
# 14325         5.0         5.0     Manual        4.0     NaN         NaN
# 14326         5.0         5.0     Manual        4.0     NaN         NaN
# 14327         5.0         5.0     Manual        4.0     NaN         NaN
# 14328         5.0         5.0     Manual        4.0     NaN         NaN
# 15574         5.0         7.0  Automatic        4.0     NaN         4WD
#
#           Fuel Emission_Class  \
# 7809   Benzine        Euro 6d
# 7810   Benzine        Euro 6d
# 7811   Benzine        Euro 6d
# 7812   Benzine        Euro 6d
# 8128   Benzine            NaN
# 10194  Benzine        Euro 6d
# 10559   Diesel            NaN
# 12467   Diesel         Euro 6
# 12473   Diesel         Euro 6
# 12484   Diesel         Euro 6
# 12499   Diesel         Euro 6
# 12501   Diesel            NaN
# 12554  Benzine         Euro 6
# 12604   Diesel         Euro 6
# 12670   Diesel         Euro 6
# 12750  Benzine            NaN
# 12768   Diesel            NaN
# 12769  Benzine         Euro 6
# 12781  Benzine         Euro 6
# 12783  Benzine         Euro 6
# 12786   Diesel         Euro 6
# 12790   Diesel         Euro 6
# 12796  Benzine         Euro 6
# 12798   Diesel         Euro 6
# 12800   Diesel         Euro 6
# 12815   Diesel         Euro 6
# 12823  Benzine         Euro 6
# 12835  Benzine         Euro 6
# 12848   Diesel         Euro 6
# 12849   Diesel         Euro 6
# 13904  Benzine            NaN
# 13912  Benzine         Euro 4
# 14198   Diesel            NaN
# 14284  Benzine            NaN
# 14314  Benzine            NaN
# 14315  Benzine            NaN
# 14319  Benzine            NaN
# 14320  Benzine            NaN
# 14321  Benzine            NaN
# 14322  Benzine            NaN
# 14324  Benzine            NaN
# 14325  Benzine            NaN
# 14326  Benzine            NaN
# 14327  Benzine            NaN
# 14328  Benzine            NaN
# 15574   Diesel            NaN
#
#                                      Comfort_Convenience  \
# 7809   Air conditioning,Armrest,Automatic climate con...
# 7810   Air conditioning,Armrest,Automatic climate con...
# 7811   Air conditioning,Armrest,Automatic climate con...
# 7812   Air conditioning,Armrest,Automatic climate con...
# 8128   Air conditioning,Automatic climate control,Cru...
# 10194  Air conditioning,Electrical side mirrors,Hill ...
# 10559  Air conditioning,Automatic climate control,Cru...
# 12467  Air conditioning,Automatic climate control,Cru...
# 12473  Air conditioning,Automatic climate control,Cru...
# 12484  Air conditioning,Automatic climate control,Cru...
# 12499  Air conditioning,Automatic climate control,Cru...
# 12501  Air conditioning,Automatic climate control,Cru...
# 12554  Air conditioning,Automatic climate control,Cru...
# 12604  Cruise control,Electrical side mirrors,Multi-f...
# 12670  Air conditioning,Armrest,Automatic climate con...
# 12750  Air conditioning,Automatic climate control,Cru...
# 12768  Air conditioning,Automatic climate control,Cru...
# 12769  Air conditioning,Automatic climate control,Cru...
# 12781  Air conditioning,Automatic climate control,Cru...
# 12783  Air conditioning,Automatic climate control,Cru...
# 12786  Air conditioning,Automatic climate control,Cru...
# 12790  Air conditioning,Automatic climate control,Cru...
# 12796  Air conditioning,Automatic climate control,Cru...
# 12798  Air conditioning,Automatic climate control,Cru...
# 12800  Air conditioning,Armrest,Automatic climate con...
# 12815  Air conditioning,Automatic climate control,Cru...
# 12823  Air conditioning,Automatic climate control,Cru...
# 12835  Air conditioning,Automatic climate control,Cru...
# 12848  Air conditioning,Automatic climate control,Aux...
# 12849  Air conditioning,Automatic climate control,Cru...
# 13904  Air conditioning,Cruise control,Electrical sid...
# 13912  Electrical side mirrors,Keyless central door l...
# 14198  Air conditioning,Keyless central door lock,Lig...
# 14284  Air conditioning,Cruise control,Electrical sid...
# 14314  Air conditioning,Cruise control,Electrical sid...
# 14315  Air conditioning,Cruise control,Electrical sid...
# 14319  Air conditioning,Cruise control,Electrical sid...
# 14320  Air conditioning,Cruise control,Electrical sid...
# 14321  Air conditioning,Cruise control,Electrical sid...
# 14322  Air conditioning,Cruise control,Electrical sid...
# 14324  Air conditioning,Cruise control,Electrical sid...
# 14325  Air conditioning,Cruise control,Electrical sid...
# 14326  Air conditioning,Cruise control,Electrical sid...
# 14327  Air conditioning,Cruise control,Electrical sid...
# 14328  Air conditioning,Cruise control,Electrical sid...
# 15574  Air conditioning,Automatic climate control,Cru...
#
#                                      Entertainment_Media  \
# 7809                     MP3,On-board computer,Radio,USB
# 7810                     MP3,On-board computer,Radio,USB
# 7811                     MP3,On-board computer,Radio,USB
# 7812                         On-board computer,Radio,USB
# 8128     Bluetooth,CD player,MP3,On-board computer,Radio
# 10194                            On-board computer,Radio
# 10559                                       Sound system
# 12467                      Bluetooth,CD player,MP3,Radio
# 12473                                          Bluetooth
# 12484                        Bluetooth,On-board computer
# 12499                        Bluetooth,On-board computer
# 12501                        Bluetooth,On-board computer
# 12554    Bluetooth,CD player,MP3,On-board computer,Radio
# 12604                        Bluetooth,On-board computer
# 12670                        Bluetooth,On-board computer
# 12750                        Bluetooth,On-board computer
# 12768   Bluetooth,Hands-free equipment,On-board computer
# 12769                        Bluetooth,On-board computer
# 12781                        Bluetooth,On-board computer
# 12783                        Bluetooth,On-board computer
# 12786                        Bluetooth,On-board computer
# 12790                        Bluetooth,On-board computer
# 12796                        Bluetooth,On-board computer
# 12798                        Bluetooth,On-board computer
# 12800    Bluetooth,CD player,MP3,On-board computer,Radio
# 12815                        Bluetooth,On-board computer
# 12823                        Bluetooth,On-board computer
# 12835    Bluetooth,CD player,MP3,On-board computer,Radio
# 12848                                  On-board computer
# 12849                        Bluetooth,On-board computer
# 13904                                                USB
# 13912              Bluetooth,MP3,On-board computer,Radio
# 14198  Bluetooth,CD player,Digital radio,MP3,On-board...
# 14284  Bluetooth,Hands-free equipment,On-board comput...
# 14314                                                USB
# 14315                                                USB
# 14319                                                USB
# 14320                                                USB
# 14321                                                USB
# 14322                                                USB
# 14324                                                USB
# 14325                                                USB
# 14326                                                USB
# 14327                                                USB
# 14328                                                USB
# 15574                                          Radio,USB
#
#                                                   Extras  \
# 7809                    Alloy wheels,Catalytic Converter
# 7810                    Alloy wheels,Catalytic Converter
# 7811                    Alloy wheels,Catalytic Converter
# 7812                    Alloy wheels,Catalytic Converter
# 8128                  Alloy wheels,Roof rack,Sport seats
# 10194                                Catalytic Converter
# 10559                                                NaN
# 12467                             Alloy wheels,Roof rack
# 12473   Alloy wheels,Roof rack,Sport package,Sport seats
# 12484                                       Alloy wheels
# 12499                           Alloy wheels,Sport seats
# 12501                                       Alloy wheels
# 12554   Alloy wheels,Roof rack,Sport seats,Voice Control
# 12604                           Alloy wheels,Sport seats
# 12670                             Alloy wheels,Roof rack
# 12750             Alloy wheels,Sport package,Sport seats
# 12768                             Alloy wheels,Roof rack
# 12769  Alloy wheels,Sport package,Sport seats,Sport s...
# 12781            Alloy wheels,Roof rack,Sport suspension
# 12783             Alloy wheels,Sport package,Sport seats
# 12786   Alloy wheels,Roof rack,Sport package,Sport seats
# 12790   Alloy wheels,Roof rack,Sport package,Sport seats
# 12796  Alloy wheels,Ski bag,Sport seats,Sport suspension
# 12798   Alloy wheels,Roof rack,Sport package,Sport seats
# 12800   Alloy wheels,Roof rack,Sport seats,Voice Control
# 12815   Alloy wheels,Roof rack,Sport package,Sport seats
# 12823                             Alloy wheels,Roof rack
# 12835                           Alloy wheels,Sport seats
# 12848   Alloy wheels,Roof rack,Sport package,Sport seats
# 12849   Alloy wheels,Roof rack,Sport package,Sport seats
# 13904                                                NaN
# 13912                                       Touch screen
# 14198                                      Voice Control
# 14284                                                NaN
# 14314                                                NaN
# 14315                                                NaN
# 14319                                                NaN
# 14320                                                NaN
# 14321                                                NaN
# 14322                                                NaN
# 14324                                                NaN
# 14325                                                NaN
# 14326                                                NaN
# 14327                                                NaN
# 14328                                                NaN
# 15574                                       Alloy wheels
#
#                                          Safety_Security  Emission_Label  \
# 7809   ABS,Central door lock,Daytime running lights,D...             4.0
# 7810   ABS,Central door lock,Daytime running lights,D...             4.0
# 7811   ABS,Central door lock,Daytime running lights,D...             4.0
# 7812   ABS,Central door lock,Daytime running lights,D...             4.0
# 8128   ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 10194  ABS,Central door lock,Daytime running lights,D...             4.0
# 10559  Blind spot monitor,Tire pressure monitoring sy...             4.0
# 12467  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12473  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12484  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12499  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12501  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12554  ABS,Blind spot monitor,Central door lock,Drive...             NaN
# 12604  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12670  ABS,Central door lock,Daytime running lights,D...             NaN
# 12750  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12768  ABS,Central door lock,Driver-side airbag,Emerg...             NaN
# 12769  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12781  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12783  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12786  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12790  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12796  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12798  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12800  ABS,Central door lock,Daytime running lights,D...             NaN
# 12815  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12823  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12835  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 12848  ABS,Central door lock,Driver-side airbag,Elect...             NaN
# 12849  ABS,Adaptive Cruise Control,Central door lock,...             NaN
# 13904  ABS,Central door lock,Daytime running lights,D...             NaN
# 13912  ABS,Power steering,Tire pressure monitoring sy...             4.0
# 14198  ABS,Central door lock,Daytime running lights,D...             NaN
# 14284  ABS,Central door lock,Daytime running lights,D...             NaN
# 14314  ABS,Central door lock,Daytime running lights,D...             NaN
# 14315  ABS,Central door lock,Daytime running lights,D...             NaN
# 14319  ABS,Central door lock,Daytime running lights,D...             NaN
# 14320  ABS,Central door lock,Daytime running lights,D...             NaN
# 14321  ABS,Central door lock,Daytime running lights,D...             NaN
# 14322  ABS,Central door lock,Daytime running lights,D...             NaN
# 14324  ABS,Central door lock,Daytime running lights,D...             NaN
# 14325  ABS,Central door lock,Daytime running lights,D...             NaN
# 14326  ABS,Central door lock,Daytime running lights,D...             NaN
# 14327  ABS,Central door lock,Daytime running lights,D...             NaN
# 14328  ABS,Central door lock,Daytime running lights,D...             NaN
# 15574              ABS,Isofix,Power steering,Side airbag             NaN
#
#        Gears  Country  Consumption_Comb  Consumption_City  \
# 7809     6.0  Germany               6.1               7.5
# 7810     6.0  Germany               6.1               7.5
# 7811     6.0  Germany               6.1               7.5
# 7812     NaN  Germany               6.1               7.5
# 8128     6.0      NaN               NaN               NaN
# 10194    NaN  Germany               5.9               7.4
# 10559    NaN      NaN               NaN               NaN
# 12467    6.0      NaN               NaN               NaN
# 12473    6.0      NaN               NaN               NaN
# 12484    6.0      NaN               NaN               NaN
# 12499    6.0      NaN               NaN               NaN
# 12501    6.0      NaN               NaN               NaN
# 12554    6.0      NaN               NaN               NaN
# 12604    6.0      NaN               NaN               NaN
# 12670    6.0      NaN               NaN               NaN
# 12750    6.0      NaN               NaN               NaN
# 12768    6.0      NaN               NaN               NaN
# 12769    6.0      NaN               NaN               NaN
# 12781    6.0      NaN               NaN               NaN
# 12783    6.0      NaN               NaN               NaN
# 12786    6.0      NaN               NaN               NaN
# 12790    6.0      NaN               NaN               NaN
# 12796    6.0      NaN               NaN               NaN
# 12798    6.0      NaN               NaN               NaN
# 12800    6.0      NaN               NaN               NaN
# 12815    6.0      NaN               NaN               NaN
# 12823    6.0      NaN               NaN               NaN
# 12835    6.0      NaN               NaN               NaN
# 12848    6.0      NaN               NaN               NaN
# 12849    6.0      NaN               NaN               NaN
# 13904    NaN      NaN               NaN               NaN
# 13912    5.0      NaN               NaN               NaN
# 14198    6.0    Italy               NaN               NaN
# 14284    5.0      NaN               NaN               NaN
# 14314    NaN      NaN               NaN               NaN
# 14315    NaN      NaN               NaN               NaN
# 14319    NaN      NaN               NaN               NaN
# 14320    NaN      NaN               NaN               NaN
# 14321    NaN      NaN               NaN               NaN
# 14322    NaN      NaN               NaN               NaN
# 14324    NaN      NaN               NaN               NaN
# 14325    NaN      NaN               NaN               NaN
# 14326    NaN      NaN               NaN               NaN
# 14327    NaN      NaN               NaN               NaN
# 14328    NaN      NaN               NaN               NaN
# 15574    6.0      NaN               NaN               NaN
#
#        Consumption_Country     Hp  Particulate_Filter Inspection_Time  \
# 7809                   5.2  110.0                   0             NaT
# 7810                   5.2  110.0                   0             NaT
# 7811                   5.2  110.0                   0             NaT
# 7812                   5.2  110.0                   0             NaT
# 8128                   NaN   92.0                   0             NaT
# 10194                  5.0   51.0                   0             NaT
# 10559                  NaN  125.0                   1             NaT
# 12467                  NaN  100.0                   1             NaT
# 12473                  NaN  100.0                   1             NaT
# 12484                  NaN  100.0                   1             NaT
# 12499                  NaN  100.0                   1             NaT
# 12501                  NaN  100.0                   1             NaT
# 12554                  NaN  121.0                   0             NaT
# 12604                  NaN  100.0                   1             NaT
# 12670                  NaN  100.0                   1             NaT
# 12750                  NaN  147.0                   0             NaT
# 12768                  NaN  100.0                   1             NaT
# 12769                  NaN  147.0                   0             NaT
# 12781                  NaN  147.0                   0             NaT
# 12783                  NaN  147.0                   0             NaT
# 12786                  NaN  100.0                   1             NaT
# 12790                  NaN  100.0                   1             NaT
# 12796                  NaN  147.0                   0             NaT
# 12798                  NaN  100.0                   1             NaT
# 12800                  NaN  125.0                   1             NaT
# 12815                  NaN  100.0                   1             NaT
# 12823                  NaN  121.0                   0             NaT
# 12835                  NaN  147.0                   0             NaT
# 12848                  NaN  100.0                   1             NaT
# 12849                  NaN  100.0                   1             NaT
# 13904                  NaN   54.0                   0      2020-03-01
# 13912                  NaN   54.0                   0      2020-11-01
# 14198                  NaN   66.0                   0             NaT
# 14284                  NaN   54.0                   0      2021-06-01
# 14314                  NaN   54.0                   0      2021-06-01
# 14315                  NaN   54.0                   0      2021-06-01
# 14319                  NaN   54.0                   0      2021-06-01
# 14320                  NaN   54.0                   0      2021-06-01
# 14321                  NaN   54.0                   0      2021-06-01
# 14322                  NaN   54.0                   0      2021-06-01
# 14324                  NaN   54.0                   0      2021-06-01
# 14325                  NaN   54.0                   0      2021-06-01
# 14326                  NaN   54.0                   0      2021-06-01
# 14327                  NaN   54.0                   0      2021-06-01
# 14328                  NaN   54.0                   0      2021-06-01
# 15574                  NaN  118.0                   0             NaT
#
#        Inspection_Situation  Warranty  Emission Upholstery_Type  \
# 7809                      1       NaN     139.0           Cloth
# 7810                      1       NaN     139.0           Cloth
# 7811                      1       NaN     139.0           Cloth
# 7812                      1       NaN     139.0           Cloth
# 8128                      0       NaN       NaN           Cloth
# 10194                     1       NaN     134.0           Cloth
# 10559                     1       NaN       NaN    Full leather
# 12467                     0       NaN       NaN    Part leather
# 12473                     0       NaN       NaN    Part leather
# 12484                     0       NaN       NaN    Part leather
# 12499                     0       NaN       NaN    Part leather
# 12501                     0       NaN       NaN    Part leather
# 12554                     0       NaN       NaN    Part leather
# 12604                     0       NaN       NaN           Cloth
# 12670                     0       NaN       NaN           Cloth
# 12750                     0       NaN       NaN    Full leather
# 12768                     0       NaN       NaN    Full leather
# 12769                     0       NaN       NaN    Full leather
# 12781                     0       NaN       NaN    Full leather
# 12783                     0       NaN       NaN    Full leather
# 12786                     0       NaN       NaN    Part leather
# 12790                     0       NaN       NaN    Part leather
# 12796                     0       NaN       NaN    Full leather
# 12798                     0       NaN       NaN    Part leather
# 12800                     0       NaN       NaN    Part leather
# 12815                     0       NaN       NaN    Full leather
# 12823                     0       NaN       NaN           Cloth
# 12835                     0       NaN       NaN    Full leather
# 12848                     0       NaN       NaN    Part leather
# 12849                     0       NaN       NaN    Full leather
# 13904                     0       NaN       NaN           Cloth
# 13912                     0       NaN       NaN           Cloth
# 14198                     0       NaN       NaN           Cloth
# 14284                     0       NaN       NaN           Cloth
# 14314                     0       NaN       NaN           Cloth
# 14315                     0       NaN       NaN           Cloth
# 14319                     0       NaN       NaN           Cloth
# 14320                     0       NaN       NaN           Cloth
# 14321                     0       NaN       NaN           Cloth
# 14322                     0       NaN       NaN           Cloth
# 14324                     0       NaN       NaN           Cloth
# 14325                     0       NaN       NaN           Cloth
# 14326                     0       NaN       NaN           Cloth
# 14327                     0       NaN       NaN           Cloth
# 14328                     0       NaN       NaN           Cloth
# 15574                     0       NaN       NaN             NaN
#
#       Upholstery_Color  Engine_Size  Age  Price_Interval      Km_Interval
# 7809             Black        139.0  0.0  (20000, 25000]       (-1, 5000]
# 7810             Black        139.0  0.0  (20000, 25000]       (-1, 5000]
# 7811             Black        139.0  0.0  (20000, 25000]       (-1, 5000]
# 7812             Black        139.0  0.0  (20000, 25000]       (-1, 5000]
# 8128             Black        140.0  0.0  (15000, 20000]       (-1, 5000]
# 10194            Black        122.0  0.0  (10000, 15000]       (-1, 5000]
# 10559            Black          2.0  3.0  (15000, 20000]  (60000, 100000]
# 12467              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12473              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12484            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12499            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12501            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12554              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12604              NaN          1.0  0.0  (25000, 30000]       (-1, 5000]
# 12670              NaN          1.0  0.0  (25000, 30000]       (-1, 5000]
# 12750            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12768            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12769            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12781              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12783              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12786            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12790            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12796              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12798              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12800              NaN          1.0  0.0  (30000, 80000]    (5000, 15000]
# 12815              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12823              NaN          1.0  0.0  (25000, 30000]       (-1, 5000]
# 12835            Black          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12848              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 12849              NaN          1.0  0.0  (30000, 80000]       (-1, 5000]
# 13904            Black          1.0  2.0      (0, 10000]   (15000, 30000]
# 13912            Black         54.0  2.0      (0, 10000]   (15000, 30000]
# 14198            Black          2.0  2.0      (0, 10000]   (30000, 60000]
# 14284            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 14314            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14315            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14319            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14320            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 14321            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14322            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 14324            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 14325            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14326            Black          1.0  1.0      (0, 10000]    (5000, 15000]
# 14327            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 14328            Black          1.0  1.0      (0, 10000]   (15000, 30000]
# 15574              NaN        160.0  0.0  (30000, 80000]       (-1, 5000]

# %%
df.loc[df[(df["Engine_Size"]>100)&(df["Engine_Size"]<200)].index,"Engine_Size"] = df[(df["Engine_Size"]>100)&(df["Engine_Size"]<200)]["Engine_Size"]*10
df.loc[df[df["Engine_Size"]==54].index,"Engine_Size"] = np.nan
df.loc[df[df["Engine_Size"]<10].index,"Engine_Size"] = df[df["Engine_Size"]<10]["Engine_Size"]*1000

# %%
df["Engine_Size"] = round(df["Engine_Size"]/1000,1)

# %%
df["Engine_Size"].value_counts(dropna=False)
# Out:
# 1.6    4756
# 1.4    2869
# 1.0    2434
# 1.5    1248
# 2.0    1131
# 1.2    1043
# 0.9     306
# 1.1     258
# 1.8     194
# NaN     155
# 2.5      20
# 1.3      12
# 1.9       2
# 1.7       2
# 2.8       1
# 3.0       1
# 4.1       1
# Name: Engine_Size, dtype: int64

# %%
sns.histplot(df["Weight"], bins=15);

# %%
df["Weight_Interval"] = pd.cut(df["Weight"],[0,1000,1200,1400,1600,1800,3000])
df["Weight_Interval"].value_counts()
# Out:
# (1200, 1400]    2894
# (1000, 1200]    2611
# (1400, 1600]    1142
# (1600, 1800]    1100
# (1800, 3000]     303
# (0, 1000]         18
# Name: Weight_Interval, dtype: int64

# %%
sns.histplot(df["Hp"], bins=15);

# %%
df["Hp_Interval"] = pd.cut(df["Hp"],[0,50,60,70,80,90,100,120,350])
df["Hp_Interval"].value_counts()
# Out:
# (80, 90]      3937
# (60, 70]      2861
# (120, 350]    1822
# (100, 120]    1795
# (50, 60]      1739
# (90, 100]     1700
# (70, 80]       471
# (0, 50]         25
# Name: Hp_Interval, dtype: int64

# %%
fillna_with3column(df,"Cylinders","Weight_Interval","Hp_Interval","Engine_Size","mode")
# Out:
# Number of NaN Before mode Function:  155
# 1.6    4756
# 1.4    2869
# 1.0    2434
# 1.5    1248
# 2.0    1131
# 1.2    1043
# 0.9     306
# 1.1     258
# 1.8     194
# NaN     155
# 2.5      20
# 1.3      12
# 1.9       2
# 1.7       2
# 2.8       1
# 3.0       1
# 4.1       1
# Name: Engine_Size, dtype: int64
# ------------------
# Number of NaN After mode Function:  139
# 1.6    4767
# 1.4    2870
# 1.0    2436
# 1.5    1248
# 2.0    1132
# 1.2    1043
# 0.9     306
# 1.1     258
# 1.8     194
# NaN     139
# 2.5      21
# 1.3      12
# 1.9       2
# 1.7       2
# 2.8       1
# 3.0       1
# 4.1       1
# Name: Engine_Size, dtype: int64
# ------------------

# %%
fillna_with3column(df,"Model","Hp_Interval","Weight_Interval","Engine_Size","mode")
# Out:
# Number of NaN Before mode Function:  139
# 1.6    4767
# 1.4    2870
# 1.0    2436
# 1.5    1248
# 2.0    1132
# 1.2    1043
# 0.9     306
# 1.1     258
# 1.8     194
# NaN     139
# 2.5      21
# 1.3      12
# 1.9       2
# 1.7       2
# 2.8       1
# 3.0       1
# 4.1       1
# Name: Engine_Size, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 1.6    4843
# 1.4    2884
# 1.0    2446
# 1.5    1286
# 2.0    1132
# 1.2    1044
# 0.9     306
# 1.1     258
# 1.8     194
# 2.5      21
# 1.3      12
# 1.9       2
# 1.7       2
# 2.8       1
# 3.0       1
# 4.1       1
# Name: Engine_Size, dtype: int64
# ------------------

# %% [markdown]
# # Cylinders

# %%
numeric_look("Cylinders")
# Out:
# ----DESCRIBE : --------
# count    9404.000000
# mean        3.794236
# std         0.418752
# min         1.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         8.000000
# Name: Cylinders, dtype: float64
# ----TOTAL NULL : --------
# 5029
# ----PERCENTAGE OF NULL : --------
# % 34.84
# ----CORELATION : --------
# Price                   0.008582
# Km                      0.211893
# Prev_Owner              0.109396
# Door_Total              0.074158
# Seat_Total              0.240205
# Cylinders               1.000000
# Weight                  0.269336
# Emission_Label          0.039168
# Gears                   0.134874
# Consumption_Comb        0.077573
# Consumption_City        0.098501
# Consumption_Country     0.074251
# Hp                      0.310986
# Particulate_Filter      0.160111
# Inspection_Situation    0.033631
# Warranty                0.199095
# Emission                0.332920
# Engine_Size             0.696087
# Age                     0.165262
# Name: Cylinders, dtype: float64
# ----VALUE COUNTS : --------
# 4.0    7410
# NaN    5029
# 3.0    1964
# 5.0      22
# 6.0       3
# 8.0       2
# 2.0       2
# 1.0       1
# Name: Cylinders, dtype: int64

# %%
sns.countplot(x="Cylinders", data=df);

# %%
df.groupby("Model")["Cylinders"].value_counts()
# Out:
# Model           Cylinders
# Audi A1         3.0          1271
#                 4.0           380
#                 8.0             1
# Audi A3         4.0          1719
#                 3.0           349
#                 5.0            21
# Opel Astra      4.0          1158
#                 3.0           170
# Opel Corsa      4.0          1298
#                 3.0             9
#                 1.0             1
# Opel Insignia   4.0          1467
#                 6.0             3
#                 2.0             1
# Renault Clio    4.0           775
#                 3.0           165
#                 5.0             1
# Renault Duster  4.0            33
# Renault Espace  4.0           580
#                 2.0             1
#                 8.0             1
# Name: Cylinders, dtype: int64

# %%
fillna_with3column(df,"Model","Engine_Size","Hp_Interval","Cylinders","mode")
# Out:
# Number of NaN Before mode Function:  5029
# 4.0    7410
# NaN    5029
# 3.0    1964
# 5.0      22
# 6.0       3
# 8.0       2
# 2.0       2
# 1.0       1
# Name: Cylinders, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 4.0    11583
# 3.0     2820
# 5.0       22
# 6.0        3
# 8.0        2
# 2.0        2
# 1.0        1
# Name: Cylinders, dtype: int64
# ------------------

# %% [markdown]
# # Weight

# %%
numeric_look("Weight")
# Out:
# ----DESCRIBE : --------
# count    8068.000000
# mean     1354.579202
# std       224.256342
# min         1.000000
# 25%      1170.000000
# 50%      1293.000000
# 75%      1487.000000
# max      2471.000000
# Name: Weight, dtype: float64
# ----TOTAL NULL : --------
# 6365
# ----PERCENTAGE OF NULL : --------
# % 44.1
# ----CORELATION : --------
# Price                   0.413675
# Km                      0.163785
# Prev_Owner              0.070493
# Door_Total              0.165643
# Seat_Total              0.306003
# Cylinders               0.284905
# Weight                  1.000000
# Emission_Label          0.021322
# Gears                   0.305033
# Consumption_Comb        0.027281
# Consumption_City        0.001840
# Consumption_Country     0.035053
# Hp                      0.582621
# Particulate_Filter      0.225370
# Inspection_Situation    0.014202
# Warranty                0.022966
# Emission                0.267368
# Engine_Size             0.567942
# Age                     0.084180
# Name: Weight, dtype: float64
# ----VALUE COUNTS : --------
# NaN       6365
# 1163.0     517
# 1360.0     320
# 1165.0     243
# 1335.0     221
#           ...
# 1213.0       1
# 1960.0       1
# 1258.0       1
# 1167.0       1
# 2037.0       1
# Name: Weight, Length: 435, dtype: int64

# %%
sns.histplot(df["Weight"], bins=15);

# %%
fillna_with3column(df,"Model","Hp_Interval","Engine_Size","Weight","mean")
# Out:
# Number of NaN Before mean Function:  6365
# NaN       6365
# 1163.0     517
# 1360.0     320
# 1165.0     243
# 1335.0     221
#           ...
# 1213.0       1
# 1960.0       1
# 1258.0       1
# 1167.0       1
# 2037.0       1
# Name: Weight, Length: 435, dtype: int64
# ------------------
# Number of NaN After mean Function:  199
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1905.000000      1
# 1565.000000      1
# 1650.000000      1
# 1705.000000      1
# 2037.000000      1
# Name: Weight, Length: 497, dtype: int64
# ------------------

# %%
fillna_with2column(df,"Model","Engine_Size","Weight","mean")
# Out:
# Number of NaN Before mean Function:  199
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1905.000000      1
# 1565.000000      1
# 1650.000000      1
# 1705.000000      1
# 2037.000000      1
# Name: Weight, Length: 497, dtype: int64
# ------------------
# Number of NaN After mean Function:  80
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1394.000000      1
# 1591.000000      1
# 1382.000000      1
# 1507.000000      1
# 2037.000000      1
# Name: Weight, Length: 512, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Engine_Size","Weight","mean")
# Out:
# Number of NaN Before ModeFunction:  80
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1394.000000      1
# 1591.000000      1
# 1382.000000      1
# 1507.000000      1
# 2037.000000      1
# Name: Weight, Length: 512, dtype: int64
# ------------------
# Number of NaN After Mode Function:  2
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1277.000000      1
# 1281.000000      1
# 1645.000000      1
# 1181.000000      1
# 2037.000000      1
# Name: Weight, Length: 517, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Model","Weight","mean")
# Out:
# Number of NaN Before ModeFunction:  2
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1277.000000      1
# 1281.000000      1
# 1645.000000      1
# 1181.000000      1
# 2037.000000      1
# Name: Weight, Length: 517, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 1177.930533    566
# 1403.990800    565
# 1163.000000    517
# 1697.718121    399
# 1183.580952    332
#               ...
# 1394.000000      1
# 1591.000000      1
# 1382.000000      1
# 1507.000000      1
# 2037.000000      1
# Name: Weight, Length: 518, dtype: int64
# ------------------

# %%
df["Weight_Interval"] = pd.cut(df["Weight"],[0,1000,1200,1400,1600,1800,3000])
df["Weight_Interval"].value_counts()
# Out:
# (1200, 1400]    4825
# (1000, 1200]    4337
# (1400, 1600]    3014
# (1600, 1800]    1893
# (1800, 3000]     332
# (0, 1000]         32
# Name: Weight_Interval, dtype: int64

# %% [markdown]
# # Emission_Label

# %%
numeric_look("Emission_Label")
# Out:
# ----DESCRIBE : --------
# count    7310.000000
# mean        3.846512
# std         0.677996
# min         1.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: Emission_Label, dtype: float64
# ----TOTAL NULL : --------
# 7123
# ----PERCENTAGE OF NULL : --------
# % 49.35
# ----CORELATION : --------
# Price                   0.096448
# Km                      0.062899
# Prev_Owner              0.109440
# Door_Total              0.096097
# Seat_Total              0.012591
# Cylinders               0.036553
# Weight                  0.008776
# Emission_Label          1.000000
# Gears                   0.139666
# Consumption_Comb        0.060375
# Consumption_City        0.110966
# Consumption_Country     0.029298
# Hp                      0.048971
# Particulate_Filter      0.034353
# Inspection_Situation    0.166477
# Warranty                0.077223
# Emission                0.091552
# Engine_Size             0.017428
# Age                     0.081954
# Name: Emission_Label, dtype: float64
# ----VALUE COUNTS : --------
# NaN    7123
# 4.0    6877
# 1.0     387
# 5.0      43
# 3.0       2
# 2.0       1
# Name: Emission_Label, dtype: int64

# %%
sns.countplot(x="Emission_Label", data=df);

# %%
df.groupby("Emission_Class")["Emission_Label"].value_counts()
# Out:
# Emission_Class  Emission_Label
# Euro 4          4.0                  5
# Euro 5          4.0                 19
#                 1.0                  2
# Euro 6          4.0               4838
#                 1.0                201
#                 5.0                 38
# Euro 6c         4.0                 72
#                 5.0                  3
# Euro 6d         4.0               1380
#                 1.0                 63
#                 5.0                  2
#                 3.0                  1
# Name: Emission_Label, dtype: int64

# %%
df.drop(columns="Emission_Label", inplace=True)

# %% [markdown]
# # Gears

# %%
numeric_look("Gears")
# Out:
# ----DESCRIBE : --------
# count    10228.000000
# mean         5.923739
# std          0.856504
# min          1.000000
# 25%          5.000000
# 50%          6.000000
# 75%          6.000000
# max         50.000000
# Name: Gears, dtype: float64
# ----TOTAL NULL : --------
# 4205
# ----PERCENTAGE OF NULL : --------
# % 29.13
# ----CORELATION : --------
# Price                   0.481410
# Km                      0.045217
# Prev_Owner              0.060802
# Door_Total              0.094636
# Seat_Total              0.086915
# Cylinders               0.090876
# Weight                  0.345579
# Gears                   1.000000
# Consumption_Comb        0.000805
# Consumption_City        0.017116
# Consumption_Country     0.020737
# Hp                      0.421235
# Particulate_Filter      0.185083
# Inspection_Situation    0.013046
# Warranty                0.016127
# Emission                0.124622
# Engine_Size             0.351808
# Age                     0.089008
# Name: Gears, dtype: float64
# ----VALUE COUNTS : --------
# 6.0     5312
# NaN     4205
# 5.0     2959
# 7.0     1747
# 8.0      199
# 9.0        4
# 1.0        2
# 3.0        2
# 2.0        1
# 50.0       1
# 4.0        1
# Name: Gears, dtype: int64

# %%
sns.countplot(x="Gears", data=df);

# %%
fillna_with3column(df,"Hp_Interval","Engine_Size","Weight_Interval", "Gears","mode")
# Out:
# Number of NaN Before mode Function:  4205
# 6.0     5312
# NaN     4205
# 5.0     2959
# 7.0     1747
# 8.0      199
# 9.0        4
# 1.0        2
# 3.0        2
# 2.0        1
# 50.0       1
# 4.0        1
# Name: Gears, dtype: int64
# ------------------
# Number of NaN After mode Function:  61
# 6.0     7908
# 5.0     4388
# 7.0     1866
# 8.0      199
# NaN       61
# 9.0        4
# 1.0        2
# 3.0        2
# 2.0        1
# 50.0       1
# 4.0        1
# Name: Gears, dtype: int64
# ------------------

# %%
fillna_with2column(df,"Engine_Size","Weight_Interval","Gears","mode")
# Out:
# Number of NaN Before mode Function:  61
# 6.0     7908
# 5.0     4388
# 7.0     1866
# 8.0      199
# NaN       61
# 9.0        4
# 1.0        2
# 3.0        2
# 2.0        1
# 50.0       1
# 4.0        1
# Name: Gears, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# 6.0     7963
# 5.0     4394
# 7.0     1866
# 8.0      199
# 9.0        4
# 1.0        2
# 3.0        2
# 2.0        1
# 50.0       1
# 4.0        1
# Name: Gears, dtype: int64
# ------------------

# %% [markdown]
# # Consumption

# %%
numeric_look("Consumption_Comb")
# Out:
# ----DESCRIBE : --------
# count    12615.000000
# mean         4.898367
# std          1.690544
# min          0.000000
# 25%          4.100000
# 50%          4.800000
# 75%          5.500000
# max         55.000000
# Name: Consumption_Comb, dtype: float64
# ----TOTAL NULL : --------
# 1818
# ----PERCENTAGE OF NULL : --------
# % 12.6
# ----CORELATION : --------
# Price                   0.157923
# Km                      0.193254
# Prev_Owner              0.124106
# Door_Total              0.020550
# Seat_Total              0.120271
# Cylinders               0.099384
# Weight                  0.047439
# Gears                   0.012009
# Consumption_Comb        1.000000
# Consumption_City        0.873565
# Consumption_Country     0.904813
# Hp                      0.205839
# Particulate_Filter      0.190706
# Inspection_Situation    0.057788
# Warranty                0.074583
# Emission                0.521212
# Engine_Size             0.014969
# Age                     0.216666
# Name: Consumption_Comb, dtype: float64
# ----VALUE COUNTS : --------
# NaN     1818
# 3.9      684
# 4.0      641
# 5.4      630
# 4.4      606
#         ...
# 33.0       1
# 50.0       1
# 1.0        1
# 46.0       1
# 11.0       1
# Name: Consumption_Comb, Length: 73, dtype: int64

# %%
sns.histplot(x="Consumption_Comb",bins=30, kde=True, data=df);

# %%
df[["Consumption_Comb","Consumption_City","Consumption_Country"]]
# Out:
#        Consumption_Comb  Consumption_City  Consumption_Country
# 0                   3.8               4.3                  3.5
# 1                   5.6               7.1                  4.7
# 2                   3.8               4.4                  3.4
# 3                   3.8               4.3                  3.5
# 4                   4.1               4.6                  3.8
# ...                 ...               ...                  ...
# 15913               6.8               8.7                  5.7
# 15914               5.3               6.2                  4.7
# 15915               7.4               9.2                  6.3
# 15916               5.3               6.2                  4.7
# 15918               6.8               8.7                  5.7
#
# [14433 rows x 3 columns]

# %%
indexofconsumption = df[df["Consumption_Comb"].isnull()][["Consumption_Country","Consumption_City"]].dropna().index
valuesofconsumption = ((df["Consumption_City"] + df["Consumption_Country"])/2/((df["Consumption_City"] + df["Consumption_Country"])/2/df["Consumption_Comb"]).mean()).loc[indexofconsumption].values
df.loc[indexofconsumption,"Consumption_Comb"] = valuesofconsumption
df['Consumption_Comb'].isnull().sum()
# Out:
# 1794

# %%
indexofconsumption = df[df["Consumption_Comb"].isnull()]["Consumption_Country"].dropna().index
valuesofconsumption = (df["Consumption_Country"]/((df["Consumption_Country"]/df["Consumption_Comb"]).mean())).loc[indexofconsumption].values
df.loc[indexofconsumption,"Consumption_Comb"] = valuesofconsumption
df['Consumption_Comb'].isnull().sum()
# Out:
# 1775

# %%
indexofconsumption = df[df["Consumption_Comb"].isnull()]["Consumption_City"].dropna().index
valuesofconsumption = (df["Consumption_City"]/((df["Consumption_City"]/df["Consumption_Comb"]).mean())).loc[indexofconsumption].values
df.loc[indexofconsumption,"Consumption_Comb"] = valuesofconsumption
df['Consumption_Comb'].isnull().sum()
# Out:
# 1775

# %%
df.drop(columns=["Consumption_City","Consumption_Country"], inplace=True)

# %%
fillna_with2column(df,"Model","Fuel","Consumption_Comb","mean")
# Out:
# Number of NaN Before mean Function:  1775
# NaN          1775
# 3.900000      684
# 4.000000      641
# 5.400000      630
# 4.400000      606
#              ...
# 43.000000       1
# 9.100000        1
# 5.558188        1
# 6.407040        1
# 11.000000       1
# Name: Consumption_Comb, Length: 87, dtype: int64
# ------------------
# Number of NaN After mean Function:  1
# 3.900000    684
# 4.000000    641
# 5.400000    630
# 4.400000    606
# 5.600000    586
#            ...
# 6.635863      1
# 6.179767      1
# 7.500000      1
# 6.407040      1
# 4.360302      1
# Name: Consumption_Comb, Length: 106, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Model","Consumption_Comb","mean")
# Out:
# Number of NaN Before ModeFunction:  1
# 3.900000    684
# 4.000000    641
# 5.400000    630
# 4.400000    606
# 5.600000    586
#            ...
# 6.635863      1
# 6.179767      1
# 7.500000      1
# 6.407040      1
# 4.360302      1
# Name: Consumption_Comb, Length: 106, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 3.900000    684
# 4.000000    641
# 5.400000    630
# 4.400000    606
# 5.600000    586
#            ...
# 6.635863      1
# 6.179767      1
# 7.500000      1
# 6.407040      1
# 4.360302      1
# Name: Consumption_Comb, Length: 106, dtype: int64
# ------------------

# %%
df.rename(columns={"Consumption_Comb" : "Consumption"}, inplace=True)

# %% [markdown]
# # Hp

# %%
numeric_look("Hp")
# Out:
# ----DESCRIBE : --------
# count    14350.000000
# mean        88.444808
# std         26.711531
# min          1.000000
# 25%         66.000000
# 50%         85.000000
# 75%        101.000000
# max        294.000000
# Name: Hp, dtype: float64
# ----TOTAL NULL : --------
# 83
# ----PERCENTAGE OF NULL : --------
# % 0.58
# ----CORELATION : --------
# Price                   0.696250
# Km                      0.012641
# Prev_Owner              0.032125
# Door_Total              0.119863
# Seat_Total              0.282662
# Cylinders               0.276350
# Weight                  0.652790
# Gears                   0.474784
# Consumption             0.201136
# Hp                      1.000000
# Particulate_Filter      0.148635
# Inspection_Situation    0.049454
# Warranty                0.076883
# Emission                0.464690
# Engine_Size             0.604733
# Age                     0.087596
# Name: Hp, dtype: float64
# ----VALUE COUNTS : --------
# 85.0     2303
# 66.0     1984
# 81.0     1255
# 100.0    1228
# 110.0    1026
#          ...
# 84.0        1
# 195.0       1
# 44.0        1
# 239.0       1
# 137.0       1
# Name: Hp, Length: 81, dtype: int64

# %%
sns.histplot(x="Hp",bins=20, kde=True, data=df);

# %%
fillna_with2column(df,"Weight_Interval","Engine_Size","Hp","mean")
# Out:
# Number of NaN Before mean Function:  83
# 85.0     2303
# 66.0     1984
# 81.0     1255
# 100.0    1228
# 110.0    1026
#          ...
# 84.0        1
# 195.0       1
# 44.0        1
# 239.0       1
# 137.0       1
# Name: Hp, Length: 81, dtype: int64
# ------------------
# Number of NaN After mean Function:  1
# 85.000000     2303
# 66.000000     1984
# 81.000000     1255
# 100.000000    1228
# 110.000000    1026
#               ...
# NaN              1
# 59.485612        1
# 92.033237        1
# 115.980668       1
# 133.000000       1
# Name: Hp, Length: 92, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Weight_Interval","Hp","mean")
# Out:
# Number of NaN Before ModeFunction:  1
# 85.000000     2303
# 66.000000     1984
# 81.000000     1255
# 100.000000    1228
# 110.000000    1026
#               ...
# NaN              1
# 59.485612        1
# 92.033237        1
# 115.980668       1
# 133.000000       1
# Name: Hp, Length: 92, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 85.000000     2303
# 66.000000     1984
# 81.000000     1255
# 100.000000    1228
# 110.000000    1026
#               ...
# 65.067774        1
# 59.485612        1
# 92.033237        1
# 115.980668       1
# 133.000000       1
# Name: Hp, Length: 92, dtype: int64
# ------------------

# %%
df["Hp_Interval"] = pd.cut(df["Hp"],[0,50,60,70,80,90,100,120,350])
df["Hp_Interval"].value_counts()
# Out:
# (80, 90]      3961
# (60, 70]      2867
# (100, 120]    1832
# (120, 350]    1831
# (50, 60]      1740
# (90, 100]     1705
# (70, 80]       472
# (0, 50]         25
# Name: Hp_Interval, dtype: int64

# %% [markdown]
# # Inspection_Time

# %%
 print("Null values in Inspection_Time column is =  %", round(df["Inspection_Time"].isnull().sum()/df.shape[0]*100,2))
# Out:
# Null values in Inspection_Time column is =  % 77.32

# %%
df["Inspection_Time"].sample(10)
# Out:
# 14075   NaT
# 5583    NaT
# 1443    NaT
# 13444   NaT
# 1772    NaT
# 4577    NaT
# 2534    NaT
# 6045    NaT
# 7687    NaT
# 8418    NaT
# Name: Inspection_Time, dtype: datetime64[ns]

# %%
df.drop(columns="Inspection_Time", inplace=True)

# %% [markdown]
# # Warranty

# %%
numeric_look("Warranty")
# Out:
# ----DESCRIBE : --------
# count    4307.000000
# mean       22.177153
# std        16.188106
# min         1.000000
# 25%        12.000000
# 50%        12.000000
# 75%        24.000000
# max        72.000000
# Name: Warranty, dtype: float64
# ----TOTAL NULL : --------
# 10126
# ----PERCENTAGE OF NULL : --------
# % 70.16
# ----CORELATION : --------
# Price                   0.191182
# Km                      0.290089
# Prev_Owner              0.113373
# Door_Total              0.027511
# Seat_Total              0.064447
# Cylinders               0.029912
# Weight                  0.056315
# Gears                   0.001838
# Consumption             0.078962
# Hp                      0.071082
# Particulate_Filter      0.031027
# Inspection_Situation    0.301098
# Warranty                1.000000
# Emission                0.178748
# Engine_Size             0.105365
# Age                     0.320912
# Name: Warranty, dtype: float64
# ----VALUE COUNTS : --------
# NaN     10126
# 12.0     2253
# 24.0     1034
# 60.0      391
# 36.0      184
# 48.0      133
# 6.0       125
# 72.0       59
# 3.0        33
# 23.0       11
# 18.0       10
# 20.0        7
# 25.0        6
# 2.0         5
# 50.0        4
# 26.0        4
# 16.0        4
# 4.0         3
# 1.0         3
# 19.0        3
# 34.0        3
# 13.0        3
# 28.0        2
# 22.0        2
# 14.0        2
# 11.0        2
# 46.0        2
# 21.0        2
# 9.0         2
# 17.0        2
# 45.0        2
# 33.0        1
# 40.0        1
# 65.0        1
# 10.0        1
# 15.0        1
# 7.0         1
# 8.0         1
# 56.0        1
# 49.0        1
# 47.0        1
# 30.0        1
# Name: Warranty, dtype: int64

# %%
df.loc[df["Warranty"].isnull() , "Warranty"] = 0
x = 0
y= 1
while y < 13:
    df.loc[(df["Warranty"] > x) & (df["Warranty"] < x+7) , "Warranty"] = y
    x += 6
    y += 1

# %%
df.drop(columns="Warranty", inplace=True)

# %% [markdown]
# # Emission

# %%
numeric_look("Emission")
# Out:
# ----DESCRIBE : --------
# count    12182.000000
# mean       118.117468
# std         20.418061
# min          0.000000
# 25%        104.000000
# 50%        116.000000
# 75%        129.000000
# max        990.000000
# Name: Emission, dtype: float64
# ----TOTAL NULL : --------
# 2251
# ----PERCENTAGE OF NULL : --------
# % 15.6
# ----CORELATION : --------
# Price                   0.311688
# Km                      0.203443
# Prev_Owner              0.138166
# Door_Total              0.035210
# Seat_Total              0.244004
# Cylinders               0.321292
# Weight                  0.270219
# Gears                   0.121465
# Consumption             0.519755
# Hp                      0.465341
# Particulate_Filter      0.120464
# Inspection_Situation    0.109199
# Emission                1.000000
# Engine_Size             0.285740
# Age                     0.263652
# Name: Emission, dtype: float64
# ----VALUE COUNTS : --------
# NaN       2251
# 120.00     651
# 97.00      504
# 99.00      479
# 102.00     469
#           ...
# 990.00       1
# 1.06         1
# 51.00        1
# 165.00       1
# 193.00       1
# Name: Emission, Length: 123, dtype: int64

# %%
sns.histplot(df[(df["Emission"] > 0) & (df["Emission"]< 300)]["Emission"], bins=20);

# %%
fillna_with3column(df,"Model","Fuel","Hp_Interval","Emission","mean")
# Out:
# Number of NaN Before mean Function:  2251
# NaN       2251
# 120.00     651
# 97.00      504
# 99.00      479
# 102.00     469
#           ...
# 990.00       1
# 1.06         1
# 51.00        1
# 165.00       1
# 193.00       1
# Name: Emission, Length: 123, dtype: int64
# ------------------
# Number of NaN After mean Function:  37
# 120.000    651
# 97.000     504
# 99.000     479
# 102.000    469
# 104.000    447
#           ...
# 184.000      1
# 14.457       1
# 13.983       1
# 181.000      1
# 193.000      1
# Name: Emission, Length: 174, dtype: int64
# ------------------

# %%
fillna_with2column(df,"Fuel","Hp_Interval","Emission","mean")
# Out:
# Number of NaN Before mean Function:  37
# 120.000    651
# 97.000     504
# 99.000     479
# 102.000    469
# 104.000    447
#           ...
# 184.000      1
# 14.457       1
# 13.983       1
# 181.000      1
# 193.000      1
# Name: Emission, Length: 174, dtype: int64
# ------------------
# Number of NaN After mean Function:  18
# 120.000    651
# 97.000     504
# 99.000     479
# 102.000    469
# 104.000    447
#           ...
# 14.457       1
# 13.983       1
# 14.000       1
# 177.000      1
# 193.000      1
# Name: Emission, Length: 177, dtype: int64
# ------------------

# %%
fillna_with1column(df,"Hp_Interval","Emission","mean")
# Out:
# Number of NaN Before ModeFunction:  18
# 120.000    651
# 97.000     504
# 99.000     479
# 102.000    469
# 104.000    447
#           ...
# 14.457       1
# 13.983       1
# 14.000       1
# 177.000      1
# 193.000      1
# Name: Emission, Length: 177, dtype: int64
# ------------------
# Number of NaN After Mode Function:  0
# 120.0    651
# 97.0     504
# 99.0     479
# 102.0    469
# 104.0    447
#         ...
# 184.0      1
# 165.0      1
# 239.0      1
# 51.0       1
# 193.0      1
# Name: Emission, Length: 178, dtype: int64
# ------------------

# %%
df["Emission_Interval"] = pd.cut(df["Emission"],[-1,100,120,140,160,200,1000])
df["Emission_Interval"].value_counts()
# Out:
# (100, 120]     6481
# (120, 140]     4022
# (-1, 100]      2234
# (140, 160]     1455
# (160, 200]      237
# (200, 1000]       4
# Name: Emission_Interval, dtype: int64

# %% [markdown]
# # Last Look for Numerical Features

# %%
df.select_dtypes(exclude="O").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14433 entries, 0 to 15918
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 14433 non-null  float64
#  1   Km                    14433 non-null  float64
#  2   Registration_Date     14433 non-null  datetime64[ns]
#  3   Prev_Owner            14433 non-null  float64
#  4   Door_Total            14433 non-null  float64
#  5   Seat_Total            14433 non-null  float64
#  6   Cylinders             14433 non-null  float64
#  7   Weight                14433 non-null  float64
#  8   Gears                 14433 non-null  float64
#  9   Consumption           14433 non-null  float64
#  10  Hp                    14433 non-null  float64
#  11  Particulate_Filter    14433 non-null  int64
#  12  Inspection_Situation  14433 non-null  int64
#  13  Emission              14433 non-null  float64
#  14  Engine_Size           14433 non-null  float64
#  15  Age                   14433 non-null  float64
#  16  Price_Interval        14433 non-null  category
#  17  Km_Interval           14433 non-null  category
#  18  Weight_Interval       14433 non-null  category
#  19  Hp_Interval           14433 non-null  category
#  20  Emission_Interval     14433 non-null  category
# dtypes: category(5), datetime64[ns](1), float64(13), int64(2)
# memory usage: 2.4 MB

# %% [markdown]
# # Categorical Features

# %%
df.select_dtypes(include="O").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14433 entries, 0 to 15918
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                14433 non-null  object
#  1   Body_Type            14387 non-null  object
#  2   Vat                  10425 non-null  object
#  3   Type                 14431 non-null  object
#  4   Body_Color           13920 non-null  object
#  5   Paint_Type           9340 non-null   object
#  6   Gear_Type            14433 non-null  object
#  7   Drive_Chain          8122 non-null   object
#  8   Fuel                 14433 non-null  object
#  9   Emission_Class       11824 non-null  object
#  10  Comfort_Convenience  13665 non-null  object
#  11  Entertainment_Media  13277 non-null  object
#  12  Extras               11865 non-null  object
#  13  Safety_Security      13625 non-null  object
#  14  Country              6975 non-null   object
#  15  Upholstery_Type      10519 non-null  object
#  16  Upholstery_Color     9760 non-null   object
# dtypes: object(17)
# memory usage: 2.5+ MB

# %%
for i in df.select_dtypes(include="O").columns:
    print(f"Null values in {i} column is =  %", round(df[i].isnull().sum()/len(df)*100,2))
# Out:
# Null values in Model column is =  % 0.0
# Null values in Body_Type column is =  % 0.32
# Null values in Vat column is =  % 27.77
# Null values in Type column is =  % 0.01
# Null values in Body_Color column is =  % 3.55
# Null values in Paint_Type column is =  % 35.29
# Null values in Gear_Type column is =  % 0.0
# Null values in Drive_Chain column is =  % 43.73
# Null values in Fuel column is =  % 0.0
# Null values in Emission_Class column is =  % 18.08
# Null values in Comfort_Convenience column is =  % 5.32
# Null values in Entertainment_Media column is =  % 8.01
# Null values in Extras column is =  % 17.79
# Null values in Safety_Security column is =  % 5.6
# Null values in Country column is =  % 51.67
# Null values in Upholstery_Type column is =  % 27.12
# Null values in Upholstery_Color column is =  % 32.38

# %%
df.describe(include="O").T
# Out:
#                      count unique  \
# Model                14433      9
# Body_Type            14387      9
# Vat                  10425      2
# Type                 14431      5
# Body_Color           13920     16
# Paint_Type            9340      3
# Gear_Type            14433      3
# Drive_Chain           8122      3
# Fuel                 14433      5
# Emission_Class       11824      5
# Comfort_Convenience  13665   6198
# Entertainment_Media  13277    346
# Extras               11865    659
# Safety_Security      13625   4443
# Country               6975     23
# Upholstery_Type      10519      6
# Upholstery_Color      9760     10
#
#                                                                    top   freq
# Model                                                          Audi A3   2813
# Body_Type                                                       Sedans   7214
# Vat                                                     VAT deductible  10000
# Type                                                              Used  10198
# Body_Color                                                       Black   3459
# Paint_Type                                                    Metallic   9009
# Gear_Type                                                       Manual   7333
# Drive_Chain                                                      front   7967
# Fuel                                                           Benzine   7746
# Emission_Class                                                  Euro 6   9699
# Comfort_Convenience  Air conditioning,Electrical side mirrors,Hill ...    184
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...   1213
# Extras                                                    Alloy wheels   2890
# Safety_Security      ABS,Central door lock,Daytime running lights,D...    483
# Country                                                        Germany   4033
# Upholstery_Type                                                  Cloth   7759
# Upholstery_Color                                                 Black   7535

# %%
def categorical_look(column1):
    print("----DESCRIBE : --------")
    print(df[column1].describe())
    print("----TOTAL NULL : --------")
    print(df[column1].isnull().sum())
    print("----PERCENTAGE OF NULL : --------")
    print("%",round(df[column1].isnull().sum() / df.shape[0]*100, 2))
    print("----VALUE COUNTS : --------")
    print(df[column1].value_counts(dropna=False))
    print("----NUMBER OF UNIQUES : --------")
    print(df[column1].nunique())

# %% [markdown]
# # Body_Type

# %%
categorical_look("Body_Type")
# Out:
# ----DESCRIBE : --------
# count      14387
# unique         9
# top       Sedans
# freq        7214
# Name: Body_Type, dtype: object
# ----TOTAL NULL : --------
# 46
# ----PERCENTAGE OF NULL : --------
# % 0.32
# ----VALUE COUNTS : --------
# Sedans           7214
# Station wagon    3306
# Compact          2697
# Van               710
# Other             284
# Transporter        87
# Off-Road           56
# NaN                46
# Coupe              25
# Convertible         8
# Name: Body_Type, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 9

# %%
df.groupby("Model")["Body_Type"].apply(set)
# Out:
# Model
# Audi A1           {Station wagon, Sedans, Compact, Coupe, Other,...
# Audi A2                                                  {Off-Road}
# Audi A3           {nan, Station wagon, Sedans, Compact, Coupe, C...
# Opel Astra        {nan, Off-Road, Station wagon, Sedans, Compact...
# Opel Corsa        {nan, Off-Road, Sedans, Transporter, Compact, ...
# Opel Insignia     {nan, Off-Road, Station wagon, Sedans, Compact...
# Renault Clio      {nan, Off-Road, Station wagon, Sedans, Transpo...
# Renault Duster                                           {Off-Road}
# Renault Espace    {nan, Off-Road, Station wagon, Sedans, Transpo...
# Name: Body_Type, dtype: object

# %%
fillna_with2column(df,"Model","Seat_Total","Body_Type","mode")
# Out:
# Number of NaN Before mode Function:  46
# Sedans           7214
# Station wagon    3306
# Compact          2697
# Van               710
# Other             284
# Transporter        87
# Off-Road           56
# NaN                46
# Coupe              25
# Convertible         8
# Name: Body_Type, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Sedans           7233
# Station wagon    3310
# Compact          2699
# Van               731
# Other             284
# Transporter        87
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: Body_Type, dtype: int64
# ------------------

# %% [markdown]
# # Vat

# %%
categorical_look("Vat")
# Out:
# ----DESCRIBE : --------
# count              10425
# unique                 2
# top       VAT deductible
# freq               10000
# Name: Vat, dtype: object
# ----TOTAL NULL : --------
# 4008
# ----PERCENTAGE OF NULL : --------
# % 27.77
# ----VALUE COUNTS : --------
# VAT deductible      10000
# NaN                  4008
# Price negotiable      425
# Name: Vat, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 2

# %%
df.loc[df["Vat"].isnull(),"Vat"] = "No_Discount"

# %% [markdown]
# # Type

# %%
categorical_look("Type")
# Out:
# ----DESCRIBE : --------
# count     14431
# unique        5
# top        Used
# freq      10198
# Name: Type, dtype: object
# ----TOTAL NULL : --------
# 2
# ----PERCENTAGE OF NULL : --------
# % 0.01
# ----VALUE COUNTS : --------
# Used              10198
# New                1426
# Pre-registered     1119
# Employee's car      907
# Demonstration       781
# NaN                   2
# Name: Type, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 5

# %%
df.groupby(["Model", "Type"]).size().unstack().rename(columns={0: "count"}).T
# Out:
# Model           Audi A1  Audi A2  Audi A3  Opel Astra  Opel Corsa  \
# Type
# Demonstration     128.0      NaN     62.0       161.0        89.0
# Employee's car    179.0      1.0    189.0       151.0       144.0
# New               269.0      NaN    272.0       234.0       128.0
# Pre-registered    131.0      NaN    244.0       116.0       300.0
# Used             1690.0      NaN   2044.0      1665.0      1394.0
#
# Model           Opel Insignia  Renault Clio  Renault Duster  Renault Espace
# Type
# Demonstration           172.0          72.0             NaN            97.0
# Employee's car          148.0          64.0             NaN            31.0
# New                     327.0         120.0            18.0            58.0
# Pre-registered           52.0         167.0             NaN           109.0
# Used                   1715.0        1083.0            16.0           591.0

# %%
fillna_with2column(df,"Km_Interval","Age","Type","mode")
# Out:
# Number of NaN Before mode Function:  2
# Used              10198
# New                1426
# Pre-registered     1119
# Employee's car      907
# Demonstration       781
# NaN                   2
# Name: Type, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Used              10200
# New                1426
# Pre-registered     1119
# Employee's car      907
# Demonstration       781
# Name: Type, dtype: int64
# ------------------

# %% [markdown]
# # Body_Color

# %%
categorical_look("Body_Color")
# Out:
# ----DESCRIBE : --------
# count     13920
# unique       16
# top       Black
# freq       3459
# Name: Body_Color, dtype: object
# ----TOTAL NULL : --------
# 513
# ----PERCENTAGE OF NULL : --------
# % 3.55
# ----VALUE COUNTS : --------
# Black     3459
# Grey      3168
# White     2989
# Silver    1536
# Blue      1330
# Red        843
# NaN        513
# Brown      265
# Green      145
# Beige       98
# Yellow      48
# Violet      18
# Black        6
# Bronze       6
# Blue         4
# Orange       3
# Gold         2
# Name: Body_Color, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 16

# %%
(df["Body_Color"] == df["Upholstery_Color"]).value_counts()
# Out:
# False    12172
# True      2261
# dtype: int64

# %%
fillna_with3column(df,"Model","Body_Type","Upholstery_Color","Body_Color","mode")
# Out:
# Number of NaN Before mode Function:  513
# Black     3459
# Grey      3168
# White     2989
# Silver    1536
# Blue      1330
# Red        843
# NaN        513
# Brown      265
# Green      145
# Beige       98
# Yellow      48
# Violet      18
# Black        6
# Bronze       6
# Blue         4
# Orange       3
# Gold         2
# Name: Body_Color, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Black     3642
# Grey      3438
# White     3045
# Silver    1536
# Blue      1330
# Red        843
# Brown      265
# Green      149
# Beige       98
# Yellow      48
# Violet      18
# Black        6
# Bronze       6
# Blue         4
# Orange       3
# Gold         2
# Name: Body_Color, dtype: int64
# ------------------

# %% [markdown]
# # Paint_Type

# %%
categorical_look("Paint_Type")
# Out:
# ----DESCRIBE : --------
# count         9340
# unique           3
# top       Metallic
# freq          9009
# Name: Paint_Type, dtype: object
# ----TOTAL NULL : --------
# 5093
# ----PERCENTAGE OF NULL : --------
# % 35.29
# ----VALUE COUNTS : --------
# Metallic       9009
# NaN            5093
# Uni/basic       325
# Perl effect       6
# Name: Paint_Type, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 3

# %%
df[["Paint_Type","Model","Body_Color","Door_Total"]].sample(50)
# Out:
#       Paint_Type           Model Body_Color  Door_Total
# 8615         NaN      Opel Corsa      White         3.0
# 15497   Metallic  Renault Espace       Grey         5.0
# 10666        NaN   Opel Insignia      Black         5.0
# 2021    Metallic         Audi A1       Grey         4.0
# 917          NaN         Audi A1      Black         5.0
# 9527    Metallic      Opel Corsa       Grey         4.0
# 9387         NaN      Opel Corsa      White         3.0
# 6288    Metallic      Opel Astra       Grey         5.0
# 9828   Uni/basic      Opel Corsa      White         5.0
# 9567    Metallic      Opel Corsa       Grey         5.0
# 15036   Metallic  Renault Espace       Grey         5.0
# 6674    Metallic      Opel Astra       Grey         5.0
# 10458        NaN   Opel Insignia      White         5.0
# 9899    Metallic      Opel Corsa      White         5.0
# 2966         NaN         Audi A3      Black         5.0
# 14505   Metallic    Renault Clio      Black         5.0
# 6176    Metallic      Opel Astra       Grey         5.0
# 4121    Metallic         Audi A3      Black         5.0
# 3641    Metallic         Audi A3       Grey         5.0
# 2610         NaN         Audi A1      White         5.0
# 10785   Metallic   Opel Insignia     Silver         5.0
# 5660    Metallic         Audi A3      Black         4.0
# 10780        NaN   Opel Insignia       Grey         5.0
# 14298        NaN    Renault Clio      White         5.0
# 5232         NaN         Audi A3      White         5.0
# 8471    Metallic      Opel Corsa      Black         4.0
# 6434    Metallic      Opel Astra       Grey         5.0
# 6513    Metallic      Opel Astra     Silver         5.0
# 6424         NaN      Opel Astra      White         5.0
# 1219         NaN         Audi A1      Black         5.0
# 13488        NaN    Renault Clio      White         5.0
# 411     Metallic         Audi A1      Black         5.0
# 15768   Metallic  Renault Espace      Black         5.0
# 2541         NaN         Audi A1        Red         5.0
# 11974   Metallic   Opel Insignia      White         5.0
# 715     Metallic         Audi A1     Silver         4.0
# 3346    Metallic         Audi A3      Black         5.0
# 8769    Metallic      Opel Corsa      Black         5.0
# 10266   Metallic      Opel Corsa       Grey         3.0
# 9929    Metallic      Opel Corsa      Black         5.0
# 14555        NaN    Renault Clio      White         5.0
# 11506   Metallic   Opel Insignia     Silver         5.0
# 6142         NaN      Opel Astra      White         5.0
# 9926    Metallic      Opel Corsa       Blue         5.0
# 15580   Metallic  Renault Espace       Grey         5.0
# 9461         NaN      Opel Corsa       Grey         5.0
# 8846    Metallic      Opel Corsa       Blue         5.0
# 6269    Metallic      Opel Astra       Grey         4.0
# 15699   Metallic  Renault Espace      Black         5.0
# 3980         NaN         Audi A3      Black         5.0

# %%
df[df["Door_Total"]<4]["Paint_Type"].value_counts()
# Out:
# Metallic     438
# Uni/basic     14
# Name: Paint_Type, dtype: int64

# %%
df.groupby("Body_Color")["Paint_Type"].value_counts()
# Out:
# Body_Color  Paint_Type
# Beige       Metallic         64
#             Uni/basic         2
# Black       Metallic       2477
#             Uni/basic        63
# Blue        Metallic        938
#             Uni/basic        17
#             Perl effect       1
# Bronze      Metallic          3
# Brown       Metallic        211
#             Perl effect       1
# Green       Metallic        111
#             Uni/basic         2
# Grey        Metallic       2563
#             Uni/basic        58
# Orange      Metallic          1
# Red         Metallic        449
#             Uni/basic        20
#             Perl effect       1
# Silver      Metallic       1334
#             Uni/basic        27
# Violet      Metallic         13
# White       Metallic        811
#             Uni/basic       134
#             Perl effect       3
# Yellow      Metallic         34
#             Uni/basic         2
# Name: Paint_Type, dtype: int64

# %%
sns.barplot(df["Model"],df["Price"],hue=df["Paint_Type"]);

# %%
fillna_with3column(df,"Model","Body_Type","Price_Interval","Paint_Type","mode")
# Out:
# Number of NaN Before mode Function:  5093
# Metallic       9009
# NaN            5093
# Uni/basic       325
# Perl effect       6
# Name: Paint_Type, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Metallic       14085
# Uni/basic        342
# Perl effect        6
# Name: Paint_Type, dtype: int64
# ------------------

# %% [markdown]
# # Drive_Chain

# %%
categorical_look("Drive_Chain")
# Out:
# ----DESCRIBE : --------
# count      8122
# unique        3
# top       front
# freq       7967
# Name: Drive_Chain, dtype: object
# ----TOTAL NULL : --------
# 6311
# ----PERCENTAGE OF NULL : --------
# % 43.73
# ----VALUE COUNTS : --------
# front    7967
# NaN      6311
# 4WD       151
# rear        4
# Name: Drive_Chain, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 3

# %%
df.groupby(["Model","Body_Type"])["Drive_Chain"].value_counts()
# Out:
# Model           Body_Type      Drive_Chain
# Audi A1         Compact        front          610
#                                4WD              2
#                 Other          front           11
#                 Sedans         front          942
#                                4WD              1
#                                              ...
# Renault Espace  Station wagon  4WD              1
#                 Transporter    front            6
#                                4WD              1
#                 Van            front          352
#                                4WD             23
# Name: Drive_Chain, Length: 62, dtype: int64

# %%
df.loc[df["Body_Type"] == "Off-Road", "Drive_Chain"] = "4WD"

# %%
fillna_with3column(df,"Model","Body_Type","Weight_Interval","Drive_Chain","mode")
# Out:
# Number of NaN Before mode Function:  6269
# front    7960
# NaN      6269
# 4WD       200
# rear        4
# Name: Drive_Chain, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# front    14229
# 4WD        200
# rear         4
# Name: Drive_Chain, dtype: int64
# ------------------

# %% [markdown]
# # Emission_Class

# %%
categorical_look("Emission_Class")
# Out:
# ----DESCRIBE : --------
# count      11824
# unique         5
# top       Euro 6
# freq        9699
# Name: Emission_Class, dtype: object
# ----TOTAL NULL : --------
# 2609
# ----PERCENTAGE OF NULL : --------
# % 18.08
# ----VALUE COUNTS : --------
# Euro 6     9699
# NaN        2609
# Euro 6d    1874
# Euro 6c     133
# Euro 5       78
# Euro 4       40
# Name: Emission_Class, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 5

# %%
df.sample(5).T
# Out:
#                                                                   13880  \
# Model                                                      Renault Clio
# Body_Type                                                        Sedans
# Price                                                            8790.0
# Vat                                                         No_Discount
# Km                                                              45369.0
# Registration_Date                                   2017-03-01 00:00:00
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                        White
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                        Manual
# Cylinders                                                           4.0
# Weight                                                      1248.847953
# Drive_Chain                                                       front
# Fuel                                                            Benzine
# Emission_Class                                                      NaN
# Comfort_Convenience   Air conditioning,Electrical side mirrors,Multi...
# Entertainment_Media                    Bluetooth,Radio,Sound system,USB
# Extras                                                     Alloy wheels
# Safety_Security        ABS,Central door lock,Power steering,Side airbag
# Gears                                                               5.0
# Country                                                             NaN
# Consumption                                                    5.475474
# Hp                                                                 66.0
# Particulate_Filter                                                    0
# Inspection_Situation                                                  0
# Emission                                                     108.765957
# Upholstery_Type                                                     NaN
# Upholstery_Color                                                  Black
# Engine_Size                                                         1.5
# Age                                                                 2.0
# Price_Interval                                               (0, 10000]
# Km_Interval                                              (30000, 60000]
# Weight_Interval                                            (1200, 1400]
# Hp_Interval                                                    (60, 70]
# Emission_Interval                                            (100, 120]
#
#                                                                   11608  \
# Model                                                     Opel Insignia
# Body_Type                                                        Sedans
# Price                                                           17980.0
# Vat                                                      VAT deductible
# Km                                                              17800.0
# Registration_Date                                   2017-08-01 00:00:00
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                        Black
# Paint_Type                                                     Metallic
# Door_Total                                                          4.0
# Seat_Total                                                          5.0
# Gear_Type                                                        Manual
# Cylinders                                                           4.0
# Weight                                                      1466.111111
# Drive_Chain                                                       front
# Fuel                                                            Benzine
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media   Bluetooth,Hands-free equipment,On-board comput...
# Extras                          Alloy wheels,Touch screen,Voice Control
# Safety_Security       ABS,Central door lock,Daytime running lights,D...
# Gears                                                               6.0
# Country                                                         Germany
# Consumption                                                         5.9
# Hp                                                                103.0
# Particulate_Filter                                                    0
# Inspection_Situation                                                  0
# Emission                                                          133.0
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                  Black
# Engine_Size                                                         1.5
# Age                                                                 2.0
# Price_Interval                                           (15000, 20000]
# Km_Interval                                              (15000, 30000]
# Weight_Interval                                            (1400, 1600]
# Hp_Interval                                                  (100, 120]
# Emission_Interval                                            (120, 140]
#
#                                                                   8119   \
# Model                                                        Opel Astra
# Body_Type                                                 Station wagon
# Price                                                           18290.0
# Vat                                                      VAT deductible
# Km                                                                 10.0
# Registration_Date                                   2019-01-01 00:00:00
# Prev_Owner                                                          0.0
# Type                                                      Demonstration
# Body_Color                                                         Grey
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                        Manual
# Cylinders                                                           4.0
# Weight                                                      1408.809249
# Drive_Chain                                                       front
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media     Bluetooth,CD player,MP3,On-board computer,Radio
# Extras                                           Alloy wheels,Roof rack
# Safety_Security       ABS,Central door lock,Daytime running lights,D...
# Gears                                                               6.0
# Country                                                             NaN
# Consumption                                                    3.971424
# Hp                                                                 81.0
# Particulate_Filter                                                    1
# Inspection_Situation                                                  0
# Emission                                                      97.207059
# Upholstery_Type                                                   Cloth
# Upholstery_Color                                                    NaN
# Engine_Size                                                         1.6
# Age                                                                 0.0
# Price_Interval                                           (15000, 20000]
# Km_Interval                                                  (-1, 5000]
# Weight_Interval                                            (1400, 1600]
# Hp_Interval                                                    (80, 90]
# Emission_Interval                                             (-1, 100]
#
#                                                                   13738  \
# Model                                                      Renault Clio
# Body_Type                                                        Sedans
# Price                                                            6900.0
# Vat                                                      VAT deductible
# Km                                                              28500.0
# Registration_Date                                   2016-03-01 00:00:00
# Prev_Owner                                                          2.0
# Type                                                               Used
# Body_Color                                                        White
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                        Manual
# Cylinders                                                           4.0
# Weight                                                           1052.0
# Drive_Chain                                                       front
# Fuel                                                            Benzine
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Cruise control,Electrical side mirrors,Hill Ho...
# Entertainment_Media                                                 NaN
# Extras                                                              NaN
# Safety_Security       ABS,Central door lock,Central door lock with r...
# Gears                                                               5.0
# Country                                                         Germany
# Consumption                                                         5.6
# Hp                                                                 54.0
# Particulate_Filter                                                    0
# Inspection_Situation                                                  0
# Emission                                                          133.0
# Upholstery_Type                                                     NaN
# Upholstery_Color                                                    NaN
# Engine_Size                                                         1.1
# Age                                                                 3.0
# Price_Interval                                               (0, 10000]
# Km_Interval                                              (15000, 30000]
# Weight_Interval                                            (1000, 1200]
# Hp_Interval                                                    (50, 60]
# Emission_Interval                                            (120, 140]
#
#                                                                   15185
# Model                                                    Renault Espace
# Body_Type                                                           Van
# Price                                                           20900.0
# Vat                                                      VAT deductible
# Km                                                              77931.0
# Registration_Date                                   2017-03-01 00:00:00
# Prev_Owner                                                          1.0
# Type                                                               Used
# Body_Color                                                         Grey
# Paint_Type                                                     Metallic
# Door_Total                                                          5.0
# Seat_Total                                                          5.0
# Gear_Type                                                     Automatic
# Cylinders                                                           4.0
# Weight                                                           2471.0
# Drive_Chain                                                       front
# Fuel                                                             Diesel
# Emission_Class                                                   Euro 6
# Comfort_Convenience   Air conditioning,Automatic climate control,Cru...
# Entertainment_Media                                     Bluetooth,Radio
# Extras                                                     Alloy wheels
# Safety_Security       ABS,Adaptive headlights,Blind spot monitor,Cen...
# Gears                                                               6.0
# Country                                                             NaN
# Consumption                                                         4.7
# Hp                                                                118.0
# Particulate_Filter                                                    1
# Inspection_Situation                                                  0
# Emission                                                          120.0
# Upholstery_Type                                            Full leather
# Upholstery_Color                                                   Blue
# Engine_Size                                                         1.6
# Age                                                                 2.0
# Price_Interval                                           (20000, 25000]
# Km_Interval                                             (60000, 100000]
# Weight_Interval                                            (1800, 3000]
# Hp_Interval                                                  (100, 120]
# Emission_Interval                                            (100, 120]

# %%
sns.barplot(x="Emission_Class" , y="Age", hue="Model" ,data=df);

# %%
fillna_with3column(df,"Model","Age","Emission_Interval","Emission_Class","mode")
# Out:
# Number of NaN Before mode Function:  2609
# Euro 6     9699
# NaN        2609
# Euro 6d    1874
# Euro 6c     133
# Euro 5       78
# Euro 4       40
# Name: Emission_Class, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Euro 6     12026
# Euro 6d     2154
# Euro 6c      133
# Euro 5        78
# Euro 4        42
# Name: Emission_Class, dtype: int64
# ------------------

# %% [markdown]
# # Country

# %%
categorical_look("Country")
# Out:
# ----DESCRIBE : --------
# count        6975
# unique         23
# top       Germany
# freq         4033
# Name: Country, dtype: object
# ----TOTAL NULL : --------
# 7458
# ----PERCENTAGE OF NULL : --------
# % 51.67
# ----VALUE COUNTS : --------
# NaN               7458
# Germany           4033
# Italy             1028
# Netherlands        461
# European Union     406
# Spain              318
# Belgium            314
# Austria            203
# Czech Republic      50
# France              38
# Poland              36
# Denmark             33
# Hungary             28
# Japan                8
# Croatia              4
# Slovakia             3
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: Country, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 23

# %%
sns.barplot(x="Country" , y="Price",data=df)
plt.xticks(rotation=90);

# %%
df.drop(columns="Country", inplace=True)

# %% [markdown]
# # Upholstery_Type

# %%
categorical_look("Upholstery_Type")
# Out:
# ----DESCRIBE : --------
# count     10519
# unique        6
# top       Cloth
# freq       7759
# Name: Upholstery_Type, dtype: object
# ----TOTAL NULL : --------
# 3914
# ----PERCENTAGE OF NULL : --------
# % 27.12
# ----VALUE COUNTS : --------
# Cloth           7759
# NaN             3914
# Part leather    1359
# Full leather     952
# Other            334
# Velour            58
# alcantara         57
# Name: Upholstery_Type, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 6

# %%
df[df["Upholstery_Type"] != "Cloth"].groupby(["Upholstery_Type","Model","Engine_Size"])["Upholstery_Color"].value_counts().to_frame().tail(50)
# Out:
#                                                              Upholstery_Color
# Upholstery_Type Model          Engine_Size Upholstery_Color
# Part leather    Renault Espace 1.6         Black                           35
#                                            Brown                           33
#                                            Grey                            11
#                                             Other                           7
#                                1.8         Black                           13
#                                             Other                           7
#                                            Brown                            7
#                                2.0         Black                           14
#                                            Brown                            4
#                                            White                            1
# Velour          Audi A1        1.0         Black                           10
#                                            Grey                             1
#                                1.4         Black                            3
#                                            Grey                             2
#                 Audi A3        1.0         Grey                             3
#                                            Black                            2
#                                1.6         Black                            6
#                                            Grey                             1
#                                2.0         Black                            1
#                 Opel Astra     1.0         Black                            1
#                                1.4         Black                            1
#                                1.6         Black                            1
#                                            Grey                             1
#                 Opel Corsa     1.2         Black                            2
#                                1.4         Black                            4
#                 Opel Insignia  1.5         Black                            1
#                 Renault Clio   1.1         Black                            2
# alcantara       Audi A1        1.0         Black                            6
#                                            Grey                             1
#                                1.4         Black                            9
#                                1.6         Black                            1
#                 Audi A3        1.4         Black                            1
#                                            Grey                             1
#                                1.5         Black                            1
#                                1.6         Black                            3
#                                             Other                           1
#                                2.0         Black                            2
#                                            Grey                             1
#                 Opel Astra     1.4         Black                            2
#                                1.6         Black                            8
#                 Opel Corsa     1.2         Grey                             1
#                                1.4          Other                           1
#                 Opel Insignia  1.6         Black                            4
#                                2.0         Black                            2
#                 Renault Clio   0.9         Grey                             1
#                                1.2         Black                            2
#                                1.5         Black                            3
#                                1.6         Black                            1
#                 Renault Espace 1.6         Black                            2
#                                            Grey                             1

# %%
fillna_with3column(df,"Model","Engine_Size","Upholstery_Color","Upholstery_Type","mode")
# Out:
# Number of NaN Before mode Function:  3914
# Cloth           7759
# NaN             3914
# Part leather    1359
# Full leather     952
# Other            334
# Velour            58
# alcantara         57
# Name: Upholstery_Type, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Cloth           11334
# Part leather     1360
# Full leather     1290
# Other             334
# Velour             58
# alcantara          57
# Name: Upholstery_Type, dtype: int64
# ------------------

# %% [markdown]
# # Upholstery_Color

# %%
categorical_look("Upholstery_Color")
# Out:
# ----DESCRIBE : --------
# count      9760
# unique       10
# top       Black
# freq       7535
# Name: Upholstery_Color, dtype: object
# ----TOTAL NULL : --------
# 4673
# ----PERCENTAGE OF NULL : --------
# % 32.38
# ----VALUE COUNTS : --------
# Black     7535
# NaN       4673
# Grey      1056
#  Other     874
# Brown      201
# Beige       51
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: Upholstery_Color, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 10

# %%
df.groupby("Body_Color")["Upholstery_Color"].value_counts()
# Out:
# Body_Color  Upholstery_Color
# Beige       Black               41
#             Grey                10
#              Other               6
#             Brown                6
#             Beige                2
#                                 ..
# White       Red                  2
#             Blue                 1
# Yellow      Black               32
#             Grey                 6
#              Other               1
# Name: Upholstery_Color, Length: 71, dtype: int64

# %%
fillna_with3column(df,"Model","Body_Color","Upholstery_Type","Upholstery_Color","mode")
# Out:
# Number of NaN Before mode Function:  4673
# Black     7535
# NaN       4673
# Grey      1056
#  Other     874
# Brown      201
# Beige       51
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: Upholstery_Color, dtype: int64
# ------------------
# Number of NaN After mode Function:  0
# Black     11780
# Grey       1072
#  Other      893
# Brown       594
# Beige        51
# Blue         16
# White        13
# Red           9
# Yellow        4
# Orange        1
# Name: Upholstery_Color, dtype: int64
# ------------------

# %% [markdown]
# # Comfort_Convenience & Entertainment_Media & Extras & Safety_Security

# %%
categorical_look("Comfort_Convenience")
# Out:
# ----DESCRIBE : --------
# count                                                 13665
# unique                                                 6198
# top       Air conditioning,Electrical side mirrors,Hill ...
# freq                                                    184
# Name: Comfort_Convenience, dtype: object
# ----TOTAL NULL : --------
# 768
# ----PERCENTAGE OF NULL : --------
# % 5.32
# ----VALUE COUNTS : --------
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  768
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   184
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               129
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                       113
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                   105
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Air conditioning,Armrest,Electrical side mirrors,Leather steering wheel,Multi-function steering wheel,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Start-stop system                                                                                                                                                                                                                                                                                             1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi-function steering wheel,Power windows,Split rear seats,Start-stop system                                                                                                                                                                                                                                                                                            1
# Air conditioning,Cruise control,Electrical side mirrors,Multi-function steering wheel,Park Distance Control,Power windows                                                                                                                                                                                                                                                                                                                                                                              1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Leather steering wheel,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Start-stop system,Tinted windows                                                                                                                                                                                     1
# Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof      1
# Name: Comfort_Convenience, Length: 6199, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 6198

# %%
df[~(df["Comfort_Convenience"].isnull())][["Model","Age"]].value_counts(dropna=False)
# Out:
# Model           Age
# Audi A3         1.0    724
# Audi A1         1.0    715
# Opel Insignia   1.0    714
# Audi A3         0.0    700
# Audi A1         0.0    670
# Audi A3         3.0    668
#                 2.0    633
# Opel Astra      1.0    633
#                 0.0    620
# Opel Corsa      1.0    611
#                 0.0    599
# Audi A1         3.0    557
# Opel Insignia   0.0    547
#                 3.0    517
# Opel Astra      3.0    483
# Opel Insignia   2.0    480
# Renault Clio    1.0    478
# Opel Astra      2.0    455
# Audi A1         2.0    382
# Opel Corsa      3.0    372
#                 2.0    327
# Renault Clio    0.0    315
#                 2.0    311
#                 3.0    301
# Renault Espace  3.0    256
#                 1.0    225
#                 0.0    213
#                 2.0    124
# Renault Duster  0.0     34
# Audi A2         1.0      1
# dtype: int64

# %%
df.loc[df["Comfort_Convenience"].isnull(),"Comfort_Convenience"] = "NoInformation"

# %%
categorical_look("Entertainment_Media")
# Out:
# ----DESCRIBE : --------
# count                                                 13277
# unique                                                  346
# top       Bluetooth,Hands-free equipment,On-board comput...
# freq                                                   1213
# Name: Entertainment_Media, dtype: object
# ----TOTAL NULL : --------
# 1156
# ----PERCENTAGE OF NULL : --------
# % 8.01
# ----VALUE COUNTS : --------
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                  1213
# NaN                                                                         1156
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB               943
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB     706
# On-board computer,Radio                                                      446
#                                                                             ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                   1
# CD player,Hands-free equipment,MP3,Radio,USB                                   1
# MP3,Radio,Sound system,USB                                                     1
# Hands-free equipment,On-board computer,Radio,Sound system                      1
# Bluetooth,Sound system,USB                                                     1
# Name: Entertainment_Media, Length: 347, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 346

# %%
df[~(df["Entertainment_Media"].isnull())][["Model","Age"]].value_counts(dropna=False)
# Out:
# Model           Age
# Audi A3         1.0    720
# Opel Insignia   1.0    708
# Audi A1         1.0    697
# Audi A3         0.0    697
#                 3.0    657
# Audi A1         0.0    653
# Audi A3         2.0    626
# Opel Astra      1.0    625
#                 0.0    610
# Opel Corsa      1.0    604
#                 0.0    585
# Audi A1         3.0    548
# Opel Insignia   0.0    537
#                 3.0    512
# Opel Astra      3.0    471
# Renault Clio    1.0    459
# Opel Insignia   2.0    456
# Opel Astra      2.0    441
# Audi A1         2.0    370
# Opel Corsa      3.0    354
#                 2.0    318
# Renault Clio    0.0    303
#                 3.0    275
#                 2.0    273
# Renault Espace  3.0    233
#                 0.0    204
#                 1.0    201
#                 2.0    105
# Renault Duster  0.0     34
# Audi A2         1.0      1
# dtype: int64

# %%
df.loc[df["Entertainment_Media"].isnull(),"Entertainment_Media"] = "NoInformation"

# %%
categorical_look("Extras")
# Out:
# ----DESCRIBE : --------
# count            11865
# unique             659
# top       Alloy wheels
# freq              2890
# Name: Extras, dtype: object
# ----TOTAL NULL : --------
# 2568
# ----PERCENTAGE OF NULL : --------
# % 17.79
# ----VALUE COUNTS : --------
# Alloy wheels                                                                                               2890
# NaN                                                                                                        2568
# Alloy wheels,Touch screen                                                                                   630
# Alloy wheels,Voice Control                                                                                  532
# Alloy wheels,Touch screen,Voice Control                                                                     511
#                                                                                                            ...
# Alloy wheels,Handicapped enabled,Shift paddles                                                                1
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control                                          1
# Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control                    1
# Name: Extras, Length: 660, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 659

# %%
df[~(df["Extras"].isnull())][["Model","Age"]].value_counts(dropna=False)
# Out:
# Model           Age
# Opel Insignia   1.0    711
# Audi A3         1.0    711
# Audi A1         1.0    677
# Audi A3         0.0    651
#                 3.0    635
#                 2.0    605
# Audi A1         0.0    603
# Opel Astra      1.0    588
#                 0.0    565
# Opel Insignia   0.0    532
# Opel Corsa      1.0    519
# Audi A1         3.0    504
# Opel Insignia   3.0    493
# Opel Corsa      0.0    440
# Opel Insignia   2.0    425
# Opel Astra      3.0    409
# Renault Clio    1.0    372
# Opel Astra      2.0    354
# Audi A1         2.0    342
# Renault Espace  3.0    241
# Renault Clio    2.0    218
# Opel Corsa      2.0    216
# Renault Espace  1.0    212
#                 0.0    208
# Opel Corsa      3.0    198
# Renault Clio    3.0    191
#                 0.0    133
# Renault Espace  2.0    110
# Audi A2         1.0      1
# Renault Duster  0.0      1
# dtype: int64

# %%
df.loc[df["Extras"].isnull(),"Extras"] = "NoInformation"

# %%
categorical_look("Safety_Security")
# Out:
# ----DESCRIBE : --------
# count                                                 13625
# unique                                                 4443
# top       ABS,Central door lock,Daytime running lights,D...
# freq                                                    483
# Name: Safety_Security, dtype: object
# ----TOTAL NULL : --------
# 808
# ----PERCENTAGE OF NULL : --------
# % 5.6
# ----VALUE COUNTS : --------
# NaN                                                                                                                                                                                                                                                                                                                                                                                     808
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                            483
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                                       444
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                 265
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                                      230
#                                                                                                                                                                                                                                                                                                                                                                                        ...
# ABS,Blind spot monitor,Central door lock,Daytime running lights,Driver drowsiness detection,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                     1
# ABS,Alarm system,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Head airbag,Immobilizer,Isofix,LED Daytime Running Lights,LED Headlights,Night view assist,Passenger-side airbag,Power steering,Rear airbag,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights      1
# ABS,Adaptive Cruise Control,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Passenger-side airbag,Power steering,Rear airbag,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                     1
# ABS,Alarm system,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Rear airbag,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                  1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition                            1
# Name: Safety_Security, Length: 4444, dtype: int64
# ----NUMBER OF UNIQUES : --------
# 4443

# %%
df[~(df["Safety_Security"].isnull())][["Model","Age"]].value_counts(dropna=False)
# Out:
# Model           Age
# Audi A3         1.0    724
# Opel Insignia   1.0    712
# Audi A1         1.0    712
# Audi A3         0.0    698
#                 3.0    668
# Audi A1         0.0    663
# Opel Astra      1.0    633
# Audi A3         2.0    631
# Opel Astra      0.0    620
# Opel Corsa      1.0    610
#                 0.0    597
# Audi A1         3.0    556
# Opel Insignia   0.0    547
#                 3.0    516
# Opel Astra      3.0    481
# Renault Clio    1.0    480
# Opel Insignia   2.0    479
# Opel Astra      2.0    452
# Audi A1         2.0    377
# Opel Corsa      3.0    366
#                 2.0    326
# Renault Clio    0.0    316
#                 2.0    312
#                 3.0    305
# Renault Espace  3.0    253
#                 1.0    222
#                 0.0    213
#                 2.0    121
# Renault Duster  0.0     34
# Audi A2         1.0      1
# dtype: int64

# %% [markdown]
# # Last Look for Categorical Features

# %%
df.select_dtypes(include="O").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14433 entries, 0 to 15918
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                14433 non-null  object
#  1   Body_Type            14433 non-null  object
#  2   Vat                  14433 non-null  object
#  3   Type                 14433 non-null  object
#  4   Body_Color           14433 non-null  object
#  5   Paint_Type           14433 non-null  object
#  6   Gear_Type            14433 non-null  object
#  7   Drive_Chain          14433 non-null  object
#  8   Fuel                 14433 non-null  object
#  9   Emission_Class       14433 non-null  object
#  10  Comfort_Convenience  14433 non-null  object
#  11  Entertainment_Media  14433 non-null  object
#  12  Extras               14433 non-null  object
#  13  Safety_Security      13625 non-null  object
#  14  Upholstery_Type      14433 non-null  object
#  15  Upholstery_Color     14433 non-null  object
# dtypes: object(16)
# memory usage: 2.4+ MB

# %%
df.columns
# Out:
# Index(['Model', 'Body_Type', 'Price', 'Vat', 'Km', 'Registration_Date',
#        'Prev_Owner', 'Type', 'Body_Color', 'Paint_Type', 'Door_Total',
#        'Seat_Total', 'Gear_Type', 'Cylinders', 'Weight', 'Drive_Chain', 'Fuel',
#        'Emission_Class', 'Comfort_Convenience', 'Entertainment_Media',
#        'Extras', 'Safety_Security', 'Gears', 'Consumption', 'Hp',
#        'Particulate_Filter', 'Inspection_Situation', 'Emission',
#        'Upholstery_Type', 'Upholstery_Color', 'Engine_Size', 'Age',
#        'Price_Interval', 'Km_Interval', 'Weight_Interval', 'Hp_Interval',
#        'Emission_Interval'],
#       dtype='object')

# %%
df.to_csv("AutoScout_Zero")
